# %% [markdown]
# <a href="https://colab.research.google.com/github/teamgaon/recommendation_algorithms_know/blob/main/20211229_hj_know.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train데이터 불러오기
#
# 각 년도별 DataFrame을 리스트에 append합니다.
#
# 리스트 인덱스별로
#
# 0: 2017년도 데이터
#
# 1: 2018년도 데이터
#
# 2: 2019년도 데이터
#
# 3: 202년도 데이터
#
# 입니다

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from glob import glob
from tqdm import tqdm
import warnings
from sklearn.preprocessing import LabelEncoder

warnings.filterwarnings(action='ignore') 
know_train = [pd.read_csv(path) for path in sorted(glob('/content/gdrive/MyDrive/KNOW/train/*.csv'))]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2017 데이터 라벨 인코딩

# %%
know2017 = know_train[0]
know2017['bq31'] = know2017['bq31'].str.replace(" ","")

# %%
know2017
# Out:
#        idx  aq1_1 aq1_2  aq2_1 aq2_2  ...  bq40 bq41_1  bq41_2 bq41_3  knowcode
# 0        0      3     3      3     3  ...     1   4000           2200    825101
# 1        1      4     5      4     5  ...     1                  2400    140204
# 2        2      3     4      3     4  ...     1   4000           2400    140204
# 3        3      3     3      3     3  ...     1   7000           3500    140601
# 4        4      4     5      3     4  ...     1   4000           2500    140204
# ...    ...    ...   ...    ...   ...  ...   ...    ...     ...    ...       ...
# 9481  9481      3     5      2     4  ...     1   5200           1800    411301
# 9482  9482      5     5      5     5  ...     1   4000           3000    151105
# 9483  9483      3     3      4     6  ...     2   2700           1500    701101
# 9484  9484      3     5      3     5  ...     1   6800           2500     25402
# 9485  9485      3     4      3     4  ...     1   4000           3700     15201
#
# [9486 rows x 156 columns]

# %%
know2017_1 = pd.DataFrame(know2017['bq31'].unique())
know2017_1
# Out:
#                               0
# 0                            없다
# 1               매타기,드라이버,가위,CAD
# 2            건축설계표,오토캐드,파이프,보일러
# 3                    토탈스테이션,SZP
# 4                    캐드,엑셀,건축도면
# ...                         ...
# 6630          컴퓨터,ERP,더존,EDI시스템
# 6631                   오토바디,PDA
# 6632         한글,편집프로그램,포토샵,일러스트
# 6633  AUTOCAD,CATIA,전문특수정비도구(툴)
# 6634                    차량관리시스템
#
# [6635 rows x 1 columns]

# %%
know2017_1 = know2017_1.values.tolist()
know2017_1
# Out:
# [['없다'],
#  ['매타기,드라이버,가위,CAD'],
#  ['건축설계표,오토캐드,파이프,보일러'],
#  ['토탈스테이션,SZP'],
#  ['캐드,엑셀,건축도면'],
#  ['볼펜'],
#  ['컴퓨터,볼펜'],
#  ['퍼티,프라이머써페이스,코라스틱프라이머'],
#  ['관제관련시스템(FDT,FOLS)'],
#  ['가스충전기,위험물취급메뉴얼,검지기,측정기'],
#  ['한글,관세총관시스템'],
#  ['국회업무망'],
#  ['PC,EXCEL,PPt'],
#  ['없음'],
#  ['드림위버,포토샵,일러스트'],
#  ['정비용공구(드라이버,측정장비등등)'],
#  ['CDW'],
#  ['웹사이트관리CMSIT프로그램(Adobe,IBM등),웹사이트데이터분석프로그램(GoogleAnglytics등)'],
#  ['석고모형,보철,금,은,마스크,보안경,컴프레셔'],
#  ['포토샵,일러스트,에프터이펙트등그래픽툴다수'],
#  ['젖병'],
#  ['카메라'],
#  ['미용도구,약품'],
#  ['컴퓨터'],
#  ['칼,도마'],
#  ['NC선반,MCT'],
#  ['프리미어,에디우스,3D맥스,에팩'],
#  ['기중기,해머,도라이버'],
#  ['mos,cad,테스터기'],
#  ['그림책,장난감,악기,그림도구,앞치마'],
#  ['절단기,절곡기'],
#  ['곡괭이,비닐,삽등'],
#  ['표준유물관리시스템,PC,장갑,문화재관리프로그램,현미경,핀셋'],
#  ['도마,칼'],
#  ['삽,괭이,린치,톱'],
#  ['손수레,삽,트럭,사육프로그램'],
#  ['바늘,실,가위,재봉틀,다리미'],
#  ['튜너,드라이버,스패너'],
#  ['경운기'],
#  ['칼,도마,위생복'],
#  ['전동드라이버,스패너,벤치'],
#  ['크링'],
#  ['니퍼,신호측정기'],
#  ['아이롱'],
#  ['용접기,도면'],
#  ['접수프로그램(네오소프트),소독도구(자외선소독기,오토클램,자불소독기),처치도구시저,포셉)'],
#  ['MAC,CAD'],
#  ['증권사별HTS,빅스,아이트레이더,퀀티와이즈,MSoffice'],
#  ['농기계들'],
#  ['공구셋트'],
#  ['교제,놀이도구들'],
#  ['에프터이펙트'],
#  ['앞치마,고무장갑'],
#  ['수첩,볼펜'],
#  ['통신장비,레더모니터'],
#  ['복권'],
#  ['로스팅기계'],
#  ['저울,칼,도마'],
#  ['쇄목기,탈묵기'],
#  ['볼펜,카드'],
#  ['화물차포크레인'],
#  ['설계캐드프로그램'],
#  ['전자축전기제조기'],
#  ['농기계들,경운기'],
#  ['악보'],
#  ['컴퓨터,엑셀'],
#  ['장갑'],
#  ['화학증착기'],
#  ['펜,만년필,잉크,HD연필,스케치북'],
#  ['엑셀,퀀티와이즈,블룸버그,HTS'],
#  ['팩'],
#  ['금융개발프로그램'],
#  ['오토바이등비닐봉투'],
#  ['PC,대본,펜,장소'],
#  ['유아관련용품(유모차,아기띠,젖병)'],
#  ['막대,관,봉'],
#  ['스위치,자동절연스트리퍼,절연뺏치,전동드라이버,계측기'],
#  ['프로젝트,스케너'],
#  ['압착탈수기,건조기'],
#  ['컴퓨터,주사,챠트지'],
#  ['환자내역프로그램,홈페이지'],
#  ['펜하고잉크,연필'],
#  ['수리도구,전동드라이버'],
#  ['각종실험장비,클렘벤치(무균상),안큐베이터'],
#  ['안전화,안전모,클링,드라이버,벤치'],
#  ['엑셀,파워포인트'],
#  ['치위생사,스켈링'],
#  ['글리피'],
#  ['스패너,용접기'],
#  ['성형기,재단기'],
#  ['컴퓨터,금융관리프로그램'],
#  ['컴퓨터,오피스(마이크로소프트)신용분석프로그램'],
#  ['트레일러'],
#  ['캐드,도면,공구,측정기'],
#  ['유니패스'],
#  ['항공기'],
#  ['데오드라이드,측량도구,레벨'],
#  ['도면,공구들'],
#  ['스페너임펙트'],
#  ['저존,이크레더블'],
#  ['심리검사(MMPI-2,SCT)'],
#  ['PC,고서적,학술연구자료,국제조약'],
#  ['각종조리기구'],
#  ['체온계등'],
#  ['컴퓨터,자바,이클립스등게임프로그램툴'],
#  ['사출기'],
#  ['NEIS업무포털'],
#  ['법전,워드,엑셀,파워포인트'],
#  ['캠퍼스,마이크로미터'],
#  ['조리사-조리도구(칼,도마,오븐,전자레인지,Pot)'],
#  ['지게차,작업일지'],
#  ['심리검사장비,PC,엑셀'],
#  ['제도용잉크,밀리펜,스케치북,색연필'],
#  ['위생복'],
#  ['장화'],
#  ['장갑,모자등'],
#  ['엑셀,PC,ERP시스템,CAD,포토샵,일러스트레이더'],
#  ['도면'],
#  ['튜닝해머'],
#  ['2D/3D프로그램,넥스,마야,프리미어,맥등'],
#  ['레이더모니터,노선프로그램'],
#  ['엑셀,한글,CAD'],
#  ['카메라,딥(시소),달리(이동차),드론'],
#  ['SPSS,실험도구'],
#  ['헬멧,안전화,도면'],
#  ['화장품,팩,전기기구,각질제거기'],
#  ['삽,장갑,곡갱이,가위'],
#  ['컴퓨터,외국어(일본어)회화프로그램,MSofficeprogram'],
#  ['MS오피스,이클립스,펌웨어개발프로그램'],
#  ['무전기'],
#  ['PC'],
#  ['Mes,ERP'],
#  ['Msoffice'],
#  ['컴퓨터,엑셀,한글,포토샵'],
#  ['컴퓨터,청진기,고객챠트'],
#  ['엑셀,트레이딩시스템'],
#  ['수갑,가스총,곤봉,무전기'],
#  ['검사장비'],
#  ['심폐소생작동기,구급차,응급간이침대,산소호흡기'],
#  ['필기도구,컴퓨터,학사일정표'],
#  ['교재,도구(교구)'],
#  ['노트북,테블릿PC,컴퓨터'],
#  ['조미료,조리기구,위생복,위생모'],
#  ['행정온나라시스템'],
#  ['줄자'],
#  ['시멘트,줄자,도면'],
#  ['휠체어,자세유지보장구'],
#  ['카메라,송신장비'],
#  ['병원홈페이지,진료내역서증'],
#  ['펜,악보,피아노등'],
#  ['컴퓨터,보험증권,보험상품'],
#  ['코팅기,접착제,도금기,부식방지화학용품'],
#  ['컴퓨터,학습교재'],
#  ['소품,의상'],
#  ['컴퓨터,전화기'],
#  ['화장품,소품'],
#  ['벽돌,콘크리트블록'],
#  ['경운기,트랙트,이양기등'],
#  ['엑셀한글,X로이스'],
#  ['오토캐드,일러스트,ppt,ecotect등'],
#  ['연마제,연마기'],
#  ['엑셀,처방전,포사케이트'],
#  ['PC,엑셀'],
#  ['미술치료사-미술도구'],
#  ['금융관련프로그램,엑셀'],
#  ['응급차량,산소호흡기,심폐작동기'],
#  ['HTS,오피스프로그램'],
#  ['주방도구'],
#  ['시험장비들'],
#  ['공구세트'],
#  ['법전,판례문,판결봉,선서문'],
#  ['필기도구,교재,기타교구,교과서'],
#  ['씨앗,비료,호미등'],
#  ['침대,크림,수건,맛사지기구등'],
#  ['지휘봉'],
#  ['가위,미싱,실,자,작업다이'],
#  ['전기톱,가위'],
#  ['상품분석데이터프로그램,삼품리스크프로그램'],
#  ['컴퓨터,자바,이클립스'],
#  ['재봉틀,가위,줄자'],
#  ['트레이딩시스템,엑셀'],
#  ['드라이버,공구'],
#  ['부황,침'],
#  ['CAD,도면'],
#  ['마스크,장갑'],
#  ['ppt,티칭,에듀나비'],
#  ['ERP,멀티채널측정기,컴파일러'],
#  ['파쇄기'],
#  ['오피스프로그램'],
#  ['블랙박스,카드결제기'],
#  ['머신,그라인더,로스팅기'],
#  ['슈캐드,솔리드윅스,AutoCAD,SPSS'],
#  ['포토샵,일러스트,플래시,플렉스'],
#  ['건조기,증류기,혼합기'],
#  ['PC,클라우드(에버노트,onedrive)'],
#  ['빨대,휴지통,커피머신,냉장고,식기류,가스,가판대,스피커,PC'],
#  ['주방도구(냄비,후라이팬등),계량기'],
#  ['가위,클리퍼'],
#  ['SPSS,JAVA,C#'],
#  ['2.5톤트럭,전지가위,장갑,린치'],
#  ['정밀공구,스캐너,렌치,드라이버등등'],
#  ['네비게이션,굴기계'],
#  ['바늘,실,원단,패턴'],
#  ['컴퓨터,전화,더존,고적리스트'],
#  ['사료,소독약'],
#  ['법전'],
#  ['아이차트'],
#  ['재활기구'],
#  ['교반기'],
#  ['주사기,설압자,포셈등등'],
#  ['pc'],
#  ['레이터모니터,무전기'],
#  ['전자문서,그래픽프로그램,디브레인프로그램'],
#  ['칼,도마,그릇'],
#  ['PC,보호장구,전기계측기,전력분석계'],
#  ['Tool'],
#  ['CAD'],
#  ['보호장갑,위생모자'],
#  ['응급앰블런스,산소호흡기,심폐작동기,응급침대(간이)'],
#  ['한글,엑셀,파워포인트,오토캐드'],
#  ['사다리,포토샵,일러스트,컴퓨터'],
#  ['수산통계프로그램'],
#  ['재단기,제조기'],
#  ['철솔,용접장비,도치팀,용정봉,작업지시서,화공약품'],
#  ['PC,사회보럼(EDI),GPS(야생동물관련업무)'],
#  ['거스름돈,복권'],
#  ['컴퓨터,교재,교구'],
#  ['철근,공구등'],
#  ['관제관련시스템'],
#  ['쇄목기,각종식물질물질'],
#  ['레미콘트럭'],
#  ['전산프로그램'],
#  ['가위,바늘,실,다리미,자'],
#  ['와이어톱,연마기'],
#  ['사무기기'],
#  ['카메라,조명기,레이저봉,측정자'],
#  ['출동자동차,무전기,전복,컴퓨터,총'],
#  ['방적,직물,편모,원단,염색'],
#  ['증거수집,보관물품,엑셀'],
#  ['포토샵,엑셀,티비페인트'],
#  ['PC,자파,리눅스'],
#  ['열처리기,열관,장갑,촉매관등'],
#  ['교사-한글,파워포인트,엑셀,프레지등'],
#  ['운동기구,맛사지용품'],
#  ['sopi'],
#  ['컴퓨터,일러스트'],
#  ['컴퓨터,필기도구'],
#  ['PC,제품의설계도,분석표'],
#  ['절단기,제본기,샌드페이퍼'],
#  ['편집프로그램'],
#  ['크레인,안전모,장갑'],
#  ['TRANSCAD,PC'],
#  ['무선통신기'],
#  ['엑셀,PC'],
#  ['쇄목기,약품,식물성물질,폐지'],
#  ['노트북,보고서,더존'],
#  ['포토샵,파워포인트'],
#  ['컴퓨터,MSofficeprogram'],
#  ['ppt,NEIS,티칭'],
#  ['캐드,PC,엑셀,MOS,전화기,토지측량기'],
#  ['컴퓨터,테블릿PC'],
#  ['워드,엑셀'],
#  ['다이어리,스케줄표'],
#  ['지게차'],
#  ['지팡이,카드,링등'],
#  ['CAD,CAM,현미경'],
#  ['드라이기,가위,빗'],
#  ['전기선,펜치등'],
#  ['침,진단기'],
#  ['PC,일정표'],
#  ['컴퓨터,솔리드웍스,ERP,CAD프로그램,시뮬레이션소프트웨어'],
#  ['시뮬레이션프로그램,SPSS'],
#  ['CAD,인디자인,레빗'],
#  ['트럭'],
#  ['카스기계(구동프로그램),속기사용키보드'],
#  ['공구'],
#  ['크레인'],
#  ['구조설계도,PC'],
#  ['편직기,가위'],
#  ['항공노선프로그램'],
#  ['도면,드라이버,렌치,망치,니퍼'],
#  ['구명복,안전벨트,산소마스크'],
#  ['트레이,안전밸트,면세품일체'],
#  ['포토샵,포토스케이프,파워디렉터,카메라,캠코더등'],
#  ['MES,ERP,화학제품계측기,전지시험기'],
#  ['주방조리기구'],
#  ['상담지,자료'],
#  ['드라이버,톱'],
#  ['절단기,철사'],
#  ['공연복,운동화'],
#  ['절단기,칼,육류용분쇄기'],
#  ['PC,원고지,팬'],
#  ['무전기,마이크'],
#  ['컴퓨터,토지측량기'],
#  ['책,컴퓨터,칠판,분필등'],
#  ['목장갑'],
#  ['절단기,나사'],
#  ['작업공구'],
#  ['시물레이션소프트웨어(Maxwell,CAD프로그램AutoCAD,SolidWorks)'],
#  ['시트지,사다리'],
#  ['보육일지,워드프로세서'],
#  ['전동드라이버,테스터기,전기인두,노트북'],
#  ['컴퓨터,자료등'],
#  ['전화기,컴퓨터'],
#  ['산소호흡기,심폐작동기,응급차량'],
#  ['C언어,자바'],
#  ['커피머신'],
#  ['무전기,마이크,운행일지'],
#  ['소품'],
#  ['비닐봉투'],
#  ['버스,운행일지,장갑'],
#  ['용접봉,토치덤'],
#  ['앞치마'],
#  ['밀링기'],
#  ['발파기,화학류'],
#  ['기계등'],
#  ['수공구'],
#  ['에프터이펙트,프리미어'],
#  ['MS_WORD,EXCEL,POWERPOINT'],
#  ['거리측정레이저자'],
#  ['AutoCAD,문서작성워드,소음계,진동계'],
#  ['기계공구'],
#  ['PC,실험도구,현미경,확대경'],
#  ['CAD,MOS,엑셀,PPT,닥터파이프'],
#  ['Pc,MS프로그램,SAs'],
#  ['사다리,복장'],
#  ['일러스트,포토샵'],
#  ['리모컨,단정한옷'],
#  ['msoffice,window,java'],
#  ['미용도구,아이롱'],
#  ['컴퓨터,오피스,캐드'],
#  ['HTML,JAVA,XML,URML'],
#  ['PC,빅데이터,클라우드,오픈소스,프로그램언어'],
#  ['케드,줄자,다리미'],
#  ['전기인두,테스터기'],
#  ['호이스트'],
#  ['정비스캐너'],
#  ['지휘봉,악보'],
#  ['발효기'],
#  ['컴퓨터,책'],
#  ['요리도구'],
#  ['망치,드라이버'],
#  ['고객카드,태블릿'],
#  ['문서작성,CAD,대벗,엑셀,한글'],
#  ['앞치마,머리수건등'],
#  ['내시경,청진기'],
#  ['모자,장갑손전등'],
#  ['테블릿PC,노트북,컴퓨터,필기도구(펜,노트,샤프)'],
#  ['PC,비쥬얼스튜디오'],
#  ['드라이버'],
#  ['프레스,진단기,벤딩기'],
#  ['서울시행정포털사이트'],
#  ['PC,팜플렛'],
#  ['음료생산하는기계들'],
#  ['보호장구,PC,엑셀,프로세스시물레이션'],
#  ['용접기,동력공구'],
#  ['문제집(교재)'],
#  ['Altium,컴파일러'],
#  ['통계프로그램'],
#  ['마이크,교재,망원경'],
#  ['PC,방송기기,헤드셋'],
#  ['연마기,망치,끌'],
#  ['진료도구,환자의무기록지,주사,약물'],
#  ['컴퓨터,보존기록물'],
#  ['태블릿PC'],
#  ['염색약,표백제,장갑'],
#  ['나이스프로그램'],
#  ['다리미,줄자,가위'],
#  ['트렉터'],
#  ['공감프로램,SPSS,언어프로그램,의사소통프로그램'],
#  ['악기,악보'],
#  ['오토캐드'],
#  ['접착제,본뜨기틀,절단기'],
#  ['안마기,온열기계등'],
#  ['마이크,악보'],
#  ['PC,법관련서류,법령집'],
#  ['안전관리'],
#  ['침대'],
#  ['PC,MSOfficeProgram'],
#  ['대본,펜,녹음장치'],
#  ['다이어리'],
#  ['필기도구'],
#  ['대본'],
#  ['컴퓨터,키보드,휴대폰,필기도구'],
#  ['밀링기,드릴링,그라인딩'],
#  ['컴퓨터,전화'],
#  ['법관련서적,서류,컴퓨터'],
#  ['압축기'],
#  ['트렉터,경운기,트럭'],
#  ['디브레인프로그램,PC,전자문서'],
#  ['태블리PC,책상,메모지'],
#  ['1톤트럭,바구니'],
#  ['요리기구,위생복,위생모,나이프,도마,식단계획표'],
#  ['상권정보시스템'],
#  ['전자차트,EMR,OCS,PACS'],
#  ['재판사무시스템,디지털회계프로그램'],
#  ['유니패스,CS자동선별검사시스템'],
#  ['공구,기구'],
#  ['오토캐드,PC'],
#  ['CAD,pmis,계측장비'],
#  ['충방전기,카티아,오토캐드'],
#  ['CO2피더기,용접기,절곡기'],
#  ['MSSQL,Editplus'],
#  ['각종분석기계,컴퓨터'],
#  ['클라리넷'],
#  ['희곡대본'],
#  ['PC,메모리디버거,컴퓨터시스템OS,응용소프트웨어툴'],
#  ['축구공,축구화,유니폼,스타킹'],
#  ['컴퓨터,회사재무제표,주식'],
#  ['전동공구'],
#  ['컴퓨터,캐드,보호장구,검지기,측정기'],
#  ['전화기,헤드셋'],
#  ['드라이버,가위,벤치'],
#  ['철솔,용접장비,도치팀,용접봉,작업지시서,화공약품'],
#  ['미용도구(가위,클리퍼,드라이기)'],
#  ['볼펜,탑승자명단,카트'],
#  ['오토바이,포스단말기'],
#  ['전자통관시스템'],
#  ['의사랑,전기수술기,C-ARM,CT-GE'],
#  ['사출성형기,장갑'],
#  ['실사프로그램,도면,이미지본드'],
#  ['컴퓨터,보안프로그램(알랩),보호장구,측정기,검지기'],
#  ['모자,장갑,장화,슬리퍼'],
#  ['PC,프로젝트,컴퓨터'],
#  ['사내프로그램,엑셀,각종미술도구등'],
#  ['PC,상권정보시스템'],
#  ['AUTOCAD법령,감리제도법'],
#  ['편집용컴퓨터프로그램'],
#  ['컴퓨터,미술도구,창작에활용할수있는사물'],
#  ['의료보험청구프로그램'],
#  ['헬레콥터,보호안경,헤드셋,계측기'],
#  ['그라인더,캐드,각종기계장비'],
#  ['노트북,컴퓨터부품'],
#  ['전동공구,헬멧,도면'],
#  ['항공장비,정밀공구,드라이버,망치,스패너,수건'],
#  ['컴퓨터,무역프로그램(실용장등)SAP,ERP'],
#  ['연장도구'],
#  ['플라스틱사출기'],
#  ['진료도구(혈액화학분석기,경비내시경,초음파)'],
#  ['PC,MSofficeprogram'],
#  ['각종계기판,컴퓨터'],
#  ['CNUcare'],
#  ['pc,visualstudio,이클립스,컴퓨터시스템os'],
#  ['시설운영전산시스템'],
#  ['Pc,office,Excel'],
#  ['탈묵기,쇄목기'],
#  ['환자차트EMR'],
#  ['드라이버,계측기,엑셀,캐드'],
#  ['도장기,도표'],
#  ['역사서적'],
#  ['자료,컴퓨터,종이,연필,볼펜'],
#  ['운동기구,재활기구'],
#  ['컴퓨터,기획서'],
#  ['용접기,그라인더'],
#  ['마술상자'],
#  ['CAD,스케치북,포토샵,일러스트레이터'],
#  ['마스크,살포기'],
#  ['성경책'],
#  ['내비게이션,장갑,택시'],
#  ['모자,장갑,장화'],
#  ['포장기계'],
#  ['PC,고서적'],
#  ['싱글페이서'],
#  ['PC,실험도구,위생복'],
#  ['프로툴프로그램'],
#  ['ERP,실험도구'],
#  ['가위,자,원사'],
#  ['셋손,장갑,줄자'],
#  ['치과진료기구,환자기록카드'],
#  ['PC,재활치료기기'],
#  ['안전모,보안경,비계'],
#  ['진단기구(manilestrefraction,tonometer,slitlamp,Autorefraction등여러가지),검사관련프로그램(OCT,optos등)'],
#  ['PC,타블랫프로그램,스케치업'],
#  ['도금장비들'],
#  ['ezspc(공정능력해석프로그램),전동드라이버,파워미터,절연저항계,내전압시험기,온도기록계등'],
#  ['실험기구,엑셀'],
#  ['델파이,파워벨더'],
#  ['킥스'],
#  ['매스매티카,엑셀'],
#  ['게이지,절곡기,용접기,리벳'],
#  ['유리칼,코킹진,경첩'],
#  ['엑셀,일러스트,포토샵'],
#  ['다양한공구들'],
#  ['제본기,절단기'],
#  ['PC,전화,각종진단도구,녹음기'],
#  ['이클립스,비주얼스튜디오,JAVA'],
#  ['한글,엑셀,파워포인트'],
#  ['시방서,용접기,단면도,견적서'],
#  ['침,뜸'],
#  ['건축감리프로그램,액셀,건축오토캐드'],
#  ['몽키스패너,용접기,각종전동공구'],
#  ['피아노'],
#  ['에어공구,미프트'],
#  ['세올행정시스템,온나나시스템'],
#  ['파이프렌찌,몽키,드라이버'],
#  ['바둑,바둑판'],
#  ['슈즈,의상'],
#  ['무전기,레이더모니터'],
#  ['리모컨,PC,빅데이터,대본'],
#  ['헤드셋,캠,PC,게임프로그램'],
#  ['MOS,컴퓨터,보안프로그램(만랩)실험분석잘비및자료,측정기'],
#  ['브로셔,SPMS시스템'],
#  ['델파이,비쥬얼베이직'],
#  ['흙손'],
#  ['튜너,수리도구'],
#  ['해설교구재(루페,돋보기)'],
#  ['온나라,새옴,BIM'],
#  ['전기기구'],
#  ['건축관련프로그램,케드'],
#  ['엔진동력계,드라이버,망치,스페너'],
#  ['포토샵,일러스트'],
#  ['PC,JAVA,C언어,백신'],
#  ['PC,고서적,고지도,외교문서,국제조약'],
#  ['노트북,명함,카달로그,계약서'],
#  ['설계프로그램,3D캐드'],
#  ['워드,회계프로그램,전화기'],
#  ['솔리드웍스'],
#  ['한글,엑셀,인터넷'],
#  ['PC,고지도,역사관련자료들'],
#  ['PC,옷감,스케치북,원단'],
#  ['한글,엑셀,파워포인트,CAD,포토샵'],
#  ['ERP,운송관리시스템'],
#  ['드라이버,망치,스패너'],
#  ['정비도구(드라이버)'],
#  ['십자가,프로젝트,성경책'],
#  ['가위,드라이기'],
#  ['사람,손,전기기계'],
#  ['대폐공구'],
#  ['척사,나사드라이버'],
#  ['교육자료,파워포인트,엑셀'],
#  ['PC,녹음프로그램,대본,마이크'],
#  ['법전,판례검색프로그램,법령문'],
#  ['안전화,장갑등'],
#  ['더존프로그램,아이패이'],
#  ['사복프로그램,컴퓨터'],
#  ['금속,전화,컴퓨터'],
#  ['작곡용지,녹음'],
#  ['나이스프로그램,진단지,워드,엑셀'],
#  ['비디오,오디오장비,현수막,행사용품,PC,마이크,PhotoShop'],
#  ['PASS,OLS컴퓨터,EMR(전자chart)'],
#  ['조립부품공정도'],
#  ['컴퓨터,포스기계,책상'],
#  ['손차,리어카'],
#  ['파워포인트,엑셀'],
#  ['볼펜,영주증'],
#  ['시터S,교과서'],
#  ['장갑,곡갱이,경운기,호미'],
#  ['PC,법무서류'],
#  ['더존'],
#  ['재봉틀'],
#  ['실험기구'],
#  ['캐드,포토샵,도면'],
#  ['미싱,초크,줄자,명세서,원단,단추,절단기,필기도구,PC'],
#  ['포스,지폐,동전,봉투'],
#  ['파워포인트,가위,자'],
#  ['카트'],
#  ['장갑,보호구'],
#  ['카스기계,녹음기'],
#  ['화물운송목록표'],
#  ['3d시뮬레이션,삼바리,건축캐드프로그램'],
#  ['RF계측기및시험툴'],
#  ['컴퓨터,메모지,볼펜'],
#  ['전동공구,드라이버,정비복및장갑,탈착기,측정기,차량및전화기'],
#  ['PC,보호장구,측정기'],
#  ['펜,포토샵,그래픽디자인,컴퓨터'],
#  ['PC,강의교제'],
#  ['언어프로그램,녹음기,상담일자관리,SPSS,MSoffice'],
#  ['PC,직업관련자료(고용안전정보망)'],
#  ['심리검사장비(MMPI,TCI,로샤등)'],
#  ['한글,포토샵,엑셀'],
#  ['컴퓨터,스마트폰포토샵,일러스트,블러그'],
#  ['애완동물용그릇'],
#  ['마야'],
#  ['업무포털시스템'],
#  ['다로카드,팥'],
#  ['전력계통해석프로그램PSS/E,운영시스템(SCsde,Has등)'],
#  ['유니트게임엔지니어,안드로이드'],
#  ['마분지,판,기타보조물'],
#  ['경운기,농기구'],
#  ['피아노,교재'],
#  ['계약서,컴퓨터,제품브로셔(팜플렛),MSofficeprogram'],
#  ['축구화,축구공,유니폼,스타킹,정강이보호대'],
#  ['드라이버,가위'],
#  ['절,불경,목탁,염주'],
#  ['캐드,엑셀,온도센서'],
#  ['컴퓨터,전화기등'],
#  ['후레시,호루라기'],
#  ['태드,스케치업,포토샵'],
#  ['그림'],
#  ['파이널컷프로,에프터이펙트'],
#  ['대리석,화강석,수치계,절단기'],
#  ['화약류,각종기구(뇌관,도화선,장약등)'],
#  ['앞치마,국자,냄비'],
#  ['컴퓨터,측량기기'],
#  ['PC,계측기'],
#  ['운송프로그램,워드,엑셀'],
#  ['농구공,농구화,운동복'],
#  ['PC,이클립스,비주얼스튜디오'],
#  ['마술도구'],
#  ['PC,내부감사프로그램(SAT)'],
#  ['각종공구,롤러등'],
#  ['스페너,망치,드라이버'],
#  ['컴퓨터,노트북'],
#  ['php,자바'],
#  ['PC,약정서'],
#  ['엑셀,파워포인트,측정계,점도계,온도계,스프레이건'],
#  ['PC,전화'],
#  ['편집프로그램,포토샵,일러스트'],
#  ['PC,자바,리눅스,유닉스'],
#  ['전기공구,드라이버'],
#  ['연마기,끌,정,망치'],
#  ['환자기록카드,치과치료기구'],
#  ['3D프로그램(Maya,3DMax,Clae,a4D,Zdrush)등'],
#  ['컴퓨터,운동기구'],
#  ['자동조립설비'],
#  ['한글,워드,엑셀'],
#  ['로스팅기계,추출기'],
#  ['문서관리프로그램(ms-office,한글)'],
#  ['원고지,연필,메모지'],
#  ['PC,엑셀,한글,빔프로젝트'],
#  ['섬유제조장치,동물털,합성섬유,식물섬유'],
#  ['재단사,가위,칼,초크,도면'],
#  ['전압전류계,드라이버등'],
#  ['코스닥컴퓨터'],
#  ['스크루드라이버,나사드라이버'],
#  ['실험도구및약품'],
#  ['엑셀,PPT,UX/UI'],
#  ['PC,EXCEL'],
#  ['금융프로그램'],
#  ['심리검사장비(MMPI,TCI)'],
#  ['방진마스크,안전모'],
#  ['철강제품도포용열침책장비,전기도금장비,아연도금봉,히터'],
#  ['쪽가위'],
#  ['감지기,보호장구'],
#  ['전기충전기,계측기,발전기'],
#  ['컴퓨터,태블릿'],
#  ['택시'],
#  ['혈압계'],
#  ['안전모'],
#  ['용접기,스패너'],
#  ['자바,프로그래밍언어'],
#  ['바코드스캐너,금전등록기'],
#  ['설계도,체크리스트'],
#  ['광파기'],
#  ['케이블'],
#  ['차량관제시스템,엑셀,워드'],
#  ['Metlab,Origin,Silvaco등'],
#  ['PPT,한글,엑셀'],
#  ['컴퓨터,혈중알콜측정기'],
#  ['대걸레,니퍼,풀,계측기'],
#  ['피아노,기타'],
#  ['열처리기계,현미경,단소황분석시'],
#  ['전기배선공구,전기시스템부품,측정기,전기계측기,PC,SAP'],
#  ['수놀이기구,몬테소리'],
#  ['PC,소프트웨어(가상현실)'],
#  ['PC,ez-balance,시그마플롯,모델링프로그램'],
#  ['엑셀,워드,종이,펜'],
#  ['컴퓨터,수업교재,엑셀'],
#  ['디자이너-포토샵,일러스트프로그램/MAC컴퓨터'],
#  ['컴퓨터,엑셀프로그램'],
#  ['경운기,트랙터,호미,낫'],
#  ['기관차,무전기,제복'],
#  ['식단,도마,칼,위생복'],
#  ['호루라기,안전봉등'],
#  ['컴퓨터악보,건반,피아노,기타'],
#  ['미싱,가위,줄자'],
#  ['마이크'],
#  ['3Dmax,Zbush'],
#  ['안전모,안전화,후레쉬(렌턴)'],
#  ['볼펜,놀이시설관련도구'],
#  ['관련서적,PC'],
#  ['컴퓨터,볼펜등'],
#  ['의상,잡화,소품'],
#  ['제안서,PC,계약서'],
#  ['연삭기,정,망치'],
#  ['랩뷰,마이컴,C언어'],
#  ['코스맵,골프카'],
#  ['컴퓨터,PPT,엑셀'],
#  ['PC,스케치업,인디자인'],
#  ['KPIS,한국가스공사배관망정보시스템'],
#  ['캐드,PC'],
#  ['MSS,실리콘,접착제'],
#  ['설계도면,PC,MQC,고려전산'],
#  ['MQC고려전산'],
#  ['금전등록기,바코드스캐너'],
#  ['절단기,절곡기,프레스기'],
#  ['PC,자바,리눅스'],
#  ['업무일지,장갑'],
#  ['유리가공장비,강회유리기계'],
#  ['의사랑'],
#  ['컴퓨터,AUTOCAD,일러스트레이터'],
#  ['더존,엑셀,PC,전화기'],
#  ['프레스,선반'],
#  ['엑셀,실험분석자료,UTH,SEM,화학물질'],
#  ['컴퓨터,한글,오피스,노트북'],
#  ['가위,원단,직각자'],
#  ['PC,SPSS,엑셀'],
#  ['자연물'],
#  ['워드,파워포인트,포토샵'],
#  ['녹음기'],
#  ['달력,일정표,PC'],
#  ['각종교재'],
#  ['분석프로그램,분석기기,소음측정기,icp'],
#  ['교재,컴퓨터,교구,필기구'],
#  ['CAD,열처리기계,탄소황분석기'],
#  ['유압측정게,엔진동력계,드라이버,망치,스케너'],
#  ['Microsoft(PPT,엑셀),한글'],
#  ['국가통합형사사법정보시스템'],
#  ['정보프로그램,감리자동화도구'],
#  ['교과서,PC,칠판'],
#  ['PC,휴대폰'],
#  ['pc,책'],
#  ['도로모토프로그램,전산분석프로그램,트랜스캐드'],
#  ['수공구,목공기계들'],
#  ['편집프로그램,일러스트,인디자인'],
#  ['재단기,원단,가위,자'],
#  ['압연기,프레스기'],
#  ['통경대,직기,통령바늘'],
#  ['화이트보드,수성펜,참고서'],
#  ['인사업무프로그램'],
#  ['하수처리기계,측정기'],
#  ['자동차,수리연장/기계,오일,기타등등'],
#  ['컴퓨터,오토캐드,워드,엑셀'],
#  ['가위'],
#  ['일러스트레이터,포토샵'],
#  ['책'],
#  ['각종공구'],
#  ['관련DB프로그램,배양기,실험도구'],
#  ['PC,EXCEL,캐드,포토샵'],
#  ['나이스'],
#  ['샘플룩,MSofficeprogram,PC,포토샵,어도비프로그램,캐드'],
#  ['통계분석프로그램,Delphi,C언어'],
#  ['MSOffice'],
#  ['스페너,드라이버,망치'],
#  ['이클립스,와이어샤크'],
#  ['PC,오리진,수치해석프로그램'],
#  ['인터콤,수공구'],
#  ['줄자,초크,연필,송곳,재봉틀,실,바늘등'],
#  ['계랑부자,로프,배,녹끝'],
#  ['바구니,포스기,유니폼'],
#  ['파이썬,PC,SPSS,DYmate'],
#  ['자,커터칼,방수비'],
#  ['오리진,PC,실험장비'],
#  ['심리검사도구,심리치료도구등'],
#  ['수산자원조사용품,용출기등'],
#  ['갈고리'],
#  ['장갑,앞치마'],
#  ['침'],
#  ['OA프로그램'],
#  ['카메라,대체측장비,PC'],
#  ['이양기,트렉터,경운기등등'],
#  ['바둑알,바둑판'],
#  ['PC,펜,국어사전'],
#  ['엑셀,통계프로그램'],
#  ['장갑,마스크,장화'],
#  ['전동드라이버,컴퓨터'],
#  ['퍼터샵,일러스트'],
#  ['도금기,코팅기,접착제'],
#  ['키보드,컴퓨터'],
#  ['안전화,안전모,장갑,마스크'],
#  ['콘데서관,송전철탑,공기예열관'],
#  ['노트북,펜,메모지'],
#  ['팜스탬프,카티아,디폼'],
#  ['전기공구'],
#  ['CAD,맥'],
#  ['가위,자'],
#  ['ENT세이버,벤츄레이터,청진기,마취기,현미경비경'],
#  ['PDA'],
#  ['충전지,소형발전기,밧데리'],
#  ['엑셀,워드,측정기'],
#  ['PC,전화기'],
#  ['제단도구,초크,바늘,칼,가위,다리미,제단'],
#  ['전자결재시스템'],
#  ['배선도,공구set,작업지시서'],
#  ['찜질기,숙뜸이,핫팩,물리치료기기'],
#  ['영산신호측정기'],
#  ['현미경,분광기,편광기'],
#  ['주방기구(칼,도마)'],
#  ['컴퓨터등'],
#  ['pc,장난감,대여관리프로그램'],
#  ['4.5노트북,곡괭이,짚,삽,전기톱'],
#  ['테스터기,저울,호모믹서,측정기,MSoffice프로그램'],
#  ['보도블럭등'],
#  ['업무포털(NEIS)'],
#  ['PC,운송일정표'],
#  ['실험도구'],
#  ['축구코치-볼,마커,몬,조끼'],
#  ['컴퓨터,실험기기'],
#  ['워드,엑셀,파워포인트'],
#  ['교재,필기구,컴퓨터'],
#  ['분석시험도구'],
#  ['페인트,에나멜,락카,스프레이,자동분부기'],
#  ['Oracle,Toad'],
#  ['초음파진단기'],
#  ['그래픽,포토샵'],
#  ['플래쉬,레이져'],
#  ['큐베이스,프로툴,PC'],
#  ['우규,기저귀,젖병,인형놀이'],
#  ['엽연초,건조기,절단기'],
#  ['포크레인,트럭'],
#  ['붓,흙손,목재졸대,회반죽바름,회반죽이떨어지는것을방지하는상실'],
#  ['음악,CD플레이,무용복'],
#  ['승복,법전,목탁'],
#  ['대본,무대의상,소품,변장도구,마이크'],
#  ['PC,국채매입프로그램'],
#  ['줄자,카메라,측량기,계산기'],
#  ['대본,의상,분장'],
#  ['골레이트장비'],
#  ['공구함,토치'],
#  ['참고문헌,엑셀'],
#  ['소형마이크,의상'],
#  ['컴퓨터,태권도복,프로그램,기본동작,겨루기등등'],
#  ['엑셀,한글,파워포인트'],
#  ['청진기,혈압기'],
#  ['컴퓨터,Adobe계열프로그램,다빈치,C4D'],
#  ['현미경,컴퓨터'],
#  ['PC,학습지,펜'],
#  ['전산시스템,처방전,조제법'],
#  ['나무'],
#  ['ERP프로그램,항공정비공구'],
#  ['게임프로그램,PC,게이밍키보드'],
#  ['컴퓨터,오피스(M/S),녹음기,한글,워드,속기전용프로그램'],
#  ['드릴,온도센서,캐드X'],
#  ['아이롱,드라이기,파머약,염색약'],
#  ['JAVA,파워포인트'],
#  ['LC,LC-MS,GC,GC-MS,ICP-MS,질소농축기,원심분리기,피펫등'],
#  ['SPSS,Amos'],
#  ['마사지베드'],
#  ['깃발'],
#  ['미싱,프레스,펀칭기.컴퓨터'],
#  ['컴퓨터,ppt'],
#  ['포토샵,일러스트,인디자인'],
#  ['PC,보험약관프로그램'],
#  ['의료정보시스템'],
#  ['가공하는기기,전고기,가공기'],
#  ['PC로보고서,실험도구,화학물질,실험분석자료'],
#  ['PC,MSSQL,일러스트레이터'],
#  ['접지저항제,후크메타,메거'],
#  ['클리패,아이롱,직떰기'],
#  ['멸균기,초음파치료기,레이저치료기,마취기,환자기록DB'],
#  ['영상편집프로그램,편집장비'],
#  ['절단기,궐련지,담배잎'],
#  ['필기도구,전화기'],
#  ['믹싱콘솔,마이크,파워앰프,등'],
#  ['말'],
#  ['kovisStayoo'],
#  ['대본,마이크,소품'],
#  ['PC,엑셀,통계프로그램'],
#  ['pc,열측정기'],
#  ['벽돌,보도블럭등'],
#  ['재단도구,포토샵,곡자'],
#  ['앞치마.교재및교구'],
#  ['청진기,X레이등'],
#  ['Excel,Word,PhotoShop'],
#  ['마스크'],
#  ['엑셀,파워포인트,책'],
#  ['딱히없다'],
#  ['AFTEREFCTS,Photoshop,Ai(Adobeprogram),다빈치'],
#  ['컴퓨터,무역통관(수출입)프로그램,ERP,SAP'],
#  ['피아노,악보,PC'],
#  ['응급구조기구,구급차,응급처치용약품'],
#  ['영업시스템(DCS,PLC)'],
#  ['PC,엑셀,MS프로그램'],
#  ['PC,대본'],
#  ['도수변환프로그램,안경태,콘택트렌즈,도수측정기계'],
#  ['젖병,트랙터'],
#  ['PC,엑셀,워드'],
#  ['기계정비공구류,설비제어프로그램'],
#  ['마야넥스,티버페인트,포토샵'],
#  ['EMR'],
#  ['컴퓨터,엑셀,워드,파워포인트'],
#  ['전공서적,교육참고자료'],
#  ['캐드,PC,도면'],
#  ['컴퓨터그래픽,3D캐드'],
#  ['냄비,국자'],
#  ['컴퓨터,계산기,필기구,유통프로그램,포스시스템'],
#  ['컴퓨터,필기도구,기타'],
#  ['엑셀,캐드,한글,파워포인트'],
#  ['분석기기에따른각각의프로그램'],
#  ['의무기록프로그램,PC,진료기구,MSofficeprogram'],
#  ['파워포인트,전공서적'],
#  ['각종운동기구'],
#  ['카메라,특수장비'],
#  ['교재,녹음기'],
#  ['직기,통령바늘'],
#  ['포토샵,인디자인'],
#  ['태드,ESS시스템,컴퓨터'],
#  ['소독기'],
#  ['컴퓨터,필기도구,의료도구'],
#  ['노트북,명함,PC,의약설명서'],
#  ['축구공,아대,축구화,유니폼'],
#  ['MS오피스,일러스트,스케치업,포토샵'],
#  ['PC,캐드프로그램,계측기'],
#  ['장갑,마스크'],
#  ['검퓨터,엑셀'],
#  ['보안시험도구,DB모델링툴'],
#  ['랩뷰,캐드'],
#  ['CNUcare,전자챠트'],
#  ['교재,PC'],
#  ['장갑,특수차'],
#  ['한글오피스'],
#  ['PCBCAD,논리제어기'],
#  ['주식거래프로그램'],
#  ['PC,T자,옷감,연필,스케치북'],
#  ['사료,축사'],
#  ['핸드피스,스켈일러,포셋,청진기'],
#  ['노트북,필기도구,MSofficeprogram'],
#  ['국회일정관리표,각종통계자료,메모지,워드'],
#  ['PC,강의시간표'],
#  ['무대설계도,캐드,컴퓨터'],
#  ['테스트기레가전기충전기'],
#  ['맥킨토시,인디자인,캐드'],
#  ['직무프로그램'],
#  ['편광기,현미경,분광기,비중액'],
#  ['엑셀,파워포인트,SPSS'],
#  ['화학교수,연구용소프트웨어'],
#  ['재료,기계등'],
#  ['명함,샘플,노트북,계약서'],
#  ['박스'],
#  ['비료살모기,방제기,사다리,장갑'],
#  ['장비,약품(소독액,해충액)'],
#  ['PC,홍진데이터,노선절류'],
#  ['판촉물,청약서,가입설계서'],
#  ['노트북,자동차'],
#  ['미술도구'],
#  ['의료기기'],
#  ['T자'],
#  ['각종분석기계들,컴퓨터'],
#  ['객실열쇠,청소도구'],
#  ['노트북'],
#  ['축구공,유니폼,축구화'],
#  ['성격책'],
#  ['PPT,Acare등'],
#  ['OPCserver,CAD,일러스트'],
#  ['인쇄기,잉크,용지'],
#  ['PC,이클립스,언어프로그램,스위그'],
#  ['보완대체의사소통어플(AAC)'],
#  ['청진기'],
#  ['컴퓨터,워드,파워포인트'],
#  ['스캐너,전동공구'],
#  ['점치는도구'],
#  ['수리도구(드라이버)'],
#  ['창고자료표,기획안,워드프로세서'],
#  ['PC,교재,교구'],
#  ['혈압기,체온기,주사기,약통'],
#  ['홍진데이터,전기충전기,캐드도면'],
#  ['나이스시스템'],
#  ['로봇시술'],
#  ['CAD,BIM'],
#  ['도면작성프로그램(오토캐드),3D렌더링프로그램(라이노,스케치업)'],
#  ['통제시스템,공정관리시스템'],
#  ['교재.,컴퓨터,관련교구'],
#  ['컨베이어밸트'],
#  ['ERP,엑셀'],
#  ['PC(감사프로그램),엑셀,SAT,ERP'],
#  ['PC,비주얼스튜디로,일러스트'],
#  ['미술도구,엑셀,파워포인트'],
#  ['모니터'],
#  ['교재,펜,태블릿PC'],
#  ['CAD,파워포인트,굴삭기,쌤스프로그램'],
#  ['교재,교구'],
#  ['컴퓨터,인트라넷,개인화기'],
#  ['분집흡입화,종합검측사,연마밀링화'],
#  ['마이크로소프트웨어프로그램,CAD,SPS'],
#  ['PC,AUTOCAD,시뮬레이션tool'],
#  ['호루라기,깃발'],
#  ['펜,종이'],
#  ['경운기,이앙기'],
#  ['녹음기,큐베이스,베가스'],
#  ['판재,석고'],
#  ['PC,교과서'],
#  ['종이,풀,가위'],
#  ['이클립스,오라클,자바'],
#  ['주사기,핀셋,청진기,가위'],
#  ['볼펜,면세품판매를위한카트'],
#  ['일러스트,포토샵,코렐드로우,인디자인,Mac,오피스,한글'],
#  ['업무용HP,컴퓨터,계산기'],
#  ['드릴,드라이버,나사'],
#  ['각종수공구및동력기계'],
#  ['쵸크,줄자,가위'],
#  ['마이크,대본,공연복'],
#  ['플래쉬,무비메이커'],
#  ['호루라기,유니폼,카드,안전보호복'],
#  ['현미경,식약청검사프로그램,비커,피펫,플라스크'],
#  ['토크렌치,글루엔트,자동드라이버'],
#  ['주사'],
#  ['PC,포토샵,MS오피스'],
#  ['엑셀'],
#  ['PC,SPSS,SAS,경제적통계자료파일'],
#  ['쉐이커,바스푼,믹싱글라스,스트레이너'],
#  ['PC,계산기,장부'],
#  ['에듀나비,엑셀,ppt'],
#  ['손전등,모자'],
#  ['오피스(MS),포토샵,3DMAX'],
#  ['사료'],
#  ['항공교통관제사-항공정보프로그램(FDT,FOLS)'],
#  ['PC,수갑'],
#  ['장애분석Tool,Java,wfc'],
#  ['시방석설계도면,캐드'],
#  ['테블릿,학습교재,펜,색연필'],
#  ...]

# %%
tool = []
for i in range(0,6635):
  tool_1 = know2017_1[i][0].split(',')
  tool.append(tool_1)
tool
# Out:
# [['없다'],
#  ['매타기', '드라이버', '가위', 'CAD'],
#  ['건축설계표', '오토캐드', '파이프', '보일러'],
#  ['토탈스테이션', 'SZP'],
#  ['캐드', '엑셀', '건축도면'],
#  ['볼펜'],
#  ['컴퓨터', '볼펜'],
#  ['퍼티', '프라이머써페이스', '코라스틱프라이머'],
#  ['관제관련시스템(FDT', 'FOLS)'],
#  ['가스충전기', '위험물취급메뉴얼', '검지기', '측정기'],
#  ['한글', '관세총관시스템'],
#  ['국회업무망'],
#  ['PC', 'EXCEL', 'PPt'],
#  ['없음'],
#  ['드림위버', '포토샵', '일러스트'],
#  ['정비용공구(드라이버', '측정장비등등)'],
#  ['CDW'],
#  ['웹사이트관리CMSIT프로그램(Adobe', 'IBM등)', '웹사이트데이터분석프로그램(GoogleAnglytics등)'],
#  ['석고모형', '보철', '금', '은', '마스크', '보안경', '컴프레셔'],
#  ['포토샵', '일러스트', '에프터이펙트등그래픽툴다수'],
#  ['젖병'],
#  ['카메라'],
#  ['미용도구', '약품'],
#  ['컴퓨터'],
#  ['칼', '도마'],
#  ['NC선반', 'MCT'],
#  ['프리미어', '에디우스', '3D맥스', '에팩'],
#  ['기중기', '해머', '도라이버'],
#  ['mos', 'cad', '테스터기'],
#  ['그림책', '장난감', '악기', '그림도구', '앞치마'],
#  ['절단기', '절곡기'],
#  ['곡괭이', '비닐', '삽등'],
#  ['표준유물관리시스템', 'PC', '장갑', '문화재관리프로그램', '현미경', '핀셋'],
#  ['도마', '칼'],
#  ['삽', '괭이', '린치', '톱'],
#  ['손수레', '삽', '트럭', '사육프로그램'],
#  ['바늘', '실', '가위', '재봉틀', '다리미'],
#  ['튜너', '드라이버', '스패너'],
#  ['경운기'],
#  ['칼', '도마', '위생복'],
#  ['전동드라이버', '스패너', '벤치'],
#  ['크링'],
#  ['니퍼', '신호측정기'],
#  ['아이롱'],
#  ['용접기', '도면'],
#  ['접수프로그램(네오소프트)', '소독도구(자외선소독기', '오토클램', '자불소독기)', '처치도구시저', '포셉)'],
#  ['MAC', 'CAD'],
#  ['증권사별HTS', '빅스', '아이트레이더', '퀀티와이즈', 'MSoffice'],
#  ['농기계들'],
#  ['공구셋트'],
#  ['교제', '놀이도구들'],
#  ['에프터이펙트'],
#  ['앞치마', '고무장갑'],
#  ['수첩', '볼펜'],
#  ['통신장비', '레더모니터'],
#  ['복권'],
#  ['로스팅기계'],
#  ['저울', '칼', '도마'],
#  ['쇄목기', '탈묵기'],
#  ['볼펜', '카드'],
#  ['화물차포크레인'],
#  ['설계캐드프로그램'],
#  ['전자축전기제조기'],
#  ['농기계들', '경운기'],
#  ['악보'],
#  ['컴퓨터', '엑셀'],
#  ['장갑'],
#  ['화학증착기'],
#  ['펜', '만년필', '잉크', 'HD연필', '스케치북'],
#  ['엑셀', '퀀티와이즈', '블룸버그', 'HTS'],
#  ['팩'],
#  ['금융개발프로그램'],
#  ['오토바이등비닐봉투'],
#  ['PC', '대본', '펜', '장소'],
#  ['유아관련용품(유모차', '아기띠', '젖병)'],
#  ['막대', '관', '봉'],
#  ['스위치', '자동절연스트리퍼', '절연뺏치', '전동드라이버', '계측기'],
#  ['프로젝트', '스케너'],
#  ['압착탈수기', '건조기'],
#  ['컴퓨터', '주사', '챠트지'],
#  ['환자내역프로그램', '홈페이지'],
#  ['펜하고잉크', '연필'],
#  ['수리도구', '전동드라이버'],
#  ['각종실험장비', '클렘벤치(무균상)', '안큐베이터'],
#  ['안전화', '안전모', '클링', '드라이버', '벤치'],
#  ['엑셀', '파워포인트'],
#  ['치위생사', '스켈링'],
#  ['글리피'],
#  ['스패너', '용접기'],
#  ['성형기', '재단기'],
#  ['컴퓨터', '금융관리프로그램'],
#  ['컴퓨터', '오피스(마이크로소프트)신용분석프로그램'],
#  ['트레일러'],
#  ['캐드', '도면', '공구', '측정기'],
#  ['유니패스'],
#  ['항공기'],
#  ['데오드라이드', '측량도구', '레벨'],
#  ['도면', '공구들'],
#  ['스페너임펙트'],
#  ['저존', '이크레더블'],
#  ['심리검사(MMPI-2', 'SCT)'],
#  ['PC', '고서적', '학술연구자료', '국제조약'],
#  ['각종조리기구'],
#  ['체온계등'],
#  ['컴퓨터', '자바', '이클립스등게임프로그램툴'],
#  ['사출기'],
#  ['NEIS업무포털'],
#  ['법전', '워드', '엑셀', '파워포인트'],
#  ['캠퍼스', '마이크로미터'],
#  ['조리사-조리도구(칼', '도마', '오븐', '전자레인지', 'Pot)'],
#  ['지게차', '작업일지'],
#  ['심리검사장비', 'PC', '엑셀'],
#  ['제도용잉크', '밀리펜', '스케치북', '색연필'],
#  ['위생복'],
#  ['장화'],
#  ['장갑', '모자등'],
#  ['엑셀', 'PC', 'ERP시스템', 'CAD', '포토샵', '일러스트레이더'],
#  ['도면'],
#  ['튜닝해머'],
#  ['2D/3D프로그램', '넥스', '마야', '프리미어', '맥등'],
#  ['레이더모니터', '노선프로그램'],
#  ['엑셀', '한글', 'CAD'],
#  ['카메라', '딥(시소)', '달리(이동차)', '드론'],
#  ['SPSS', '실험도구'],
#  ['헬멧', '안전화', '도면'],
#  ['화장품', '팩', '전기기구', '각질제거기'],
#  ['삽', '장갑', '곡갱이', '가위'],
#  ['컴퓨터', '외국어(일본어)회화프로그램', 'MSofficeprogram'],
#  ['MS오피스', '이클립스', '펌웨어개발프로그램'],
#  ['무전기'],
#  ['PC'],
#  ['Mes', 'ERP'],
#  ['Msoffice'],
#  ['컴퓨터', '엑셀', '한글', '포토샵'],
#  ['컴퓨터', '청진기', '고객챠트'],
#  ['엑셀', '트레이딩시스템'],
#  ['수갑', '가스총', '곤봉', '무전기'],
#  ['검사장비'],
#  ['심폐소생작동기', '구급차', '응급간이침대', '산소호흡기'],
#  ['필기도구', '컴퓨터', '학사일정표'],
#  ['교재', '도구(교구)'],
#  ['노트북', '테블릿PC', '컴퓨터'],
#  ['조미료', '조리기구', '위생복', '위생모'],
#  ['행정온나라시스템'],
#  ['줄자'],
#  ['시멘트', '줄자', '도면'],
#  ['휠체어', '자세유지보장구'],
#  ['카메라', '송신장비'],
#  ['병원홈페이지', '진료내역서증'],
#  ['펜', '악보', '피아노등'],
#  ['컴퓨터', '보험증권', '보험상품'],
#  ['코팅기', '접착제', '도금기', '부식방지화학용품'],
#  ['컴퓨터', '학습교재'],
#  ['소품', '의상'],
#  ['컴퓨터', '전화기'],
#  ['화장품', '소품'],
#  ['벽돌', '콘크리트블록'],
#  ['경운기', '트랙트', '이양기등'],
#  ['엑셀한글', 'X로이스'],
#  ['오토캐드', '일러스트', 'ppt', 'ecotect등'],
#  ['연마제', '연마기'],
#  ['엑셀', '처방전', '포사케이트'],
#  ['PC', '엑셀'],
#  ['미술치료사-미술도구'],
#  ['금융관련프로그램', '엑셀'],
#  ['응급차량', '산소호흡기', '심폐작동기'],
#  ['HTS', '오피스프로그램'],
#  ['주방도구'],
#  ['시험장비들'],
#  ['공구세트'],
#  ['법전', '판례문', '판결봉', '선서문'],
#  ['필기도구', '교재', '기타교구', '교과서'],
#  ['씨앗', '비료', '호미등'],
#  ['침대', '크림', '수건', '맛사지기구등'],
#  ['지휘봉'],
#  ['가위', '미싱', '실', '자', '작업다이'],
#  ['전기톱', '가위'],
#  ['상품분석데이터프로그램', '삼품리스크프로그램'],
#  ['컴퓨터', '자바', '이클립스'],
#  ['재봉틀', '가위', '줄자'],
#  ['트레이딩시스템', '엑셀'],
#  ['드라이버', '공구'],
#  ['부황', '침'],
#  ['CAD', '도면'],
#  ['마스크', '장갑'],
#  ['ppt', '티칭', '에듀나비'],
#  ['ERP', '멀티채널측정기', '컴파일러'],
#  ['파쇄기'],
#  ['오피스프로그램'],
#  ['블랙박스', '카드결제기'],
#  ['머신', '그라인더', '로스팅기'],
#  ['슈캐드', '솔리드윅스', 'AutoCAD', 'SPSS'],
#  ['포토샵', '일러스트', '플래시', '플렉스'],
#  ['건조기', '증류기', '혼합기'],
#  ['PC', '클라우드(에버노트', 'onedrive)'],
#  ['빨대', '휴지통', '커피머신', '냉장고', '식기류', '가스', '가판대', '스피커', 'PC'],
#  ['주방도구(냄비', '후라이팬등)', '계량기'],
#  ['가위', '클리퍼'],
#  ['SPSS', 'JAVA', 'C#'],
#  ['2.5톤트럭', '전지가위', '장갑', '린치'],
#  ['정밀공구', '스캐너', '렌치', '드라이버등등'],
#  ['네비게이션', '굴기계'],
#  ['바늘', '실', '원단', '패턴'],
#  ['컴퓨터', '전화', '더존', '고적리스트'],
#  ['사료', '소독약'],
#  ['법전'],
#  ['아이차트'],
#  ['재활기구'],
#  ['교반기'],
#  ['주사기', '설압자', '포셈등등'],
#  ['pc'],
#  ['레이터모니터', '무전기'],
#  ['전자문서', '그래픽프로그램', '디브레인프로그램'],
#  ['칼', '도마', '그릇'],
#  ['PC', '보호장구', '전기계측기', '전력분석계'],
#  ['Tool'],
#  ['CAD'],
#  ['보호장갑', '위생모자'],
#  ['응급앰블런스', '산소호흡기', '심폐작동기', '응급침대(간이)'],
#  ['한글', '엑셀', '파워포인트', '오토캐드'],
#  ['사다리', '포토샵', '일러스트', '컴퓨터'],
#  ['수산통계프로그램'],
#  ['재단기', '제조기'],
#  ['철솔', '용접장비', '도치팀', '용정봉', '작업지시서', '화공약품'],
#  ['PC', '사회보럼(EDI)', 'GPS(야생동물관련업무)'],
#  ['거스름돈', '복권'],
#  ['컴퓨터', '교재', '교구'],
#  ['철근', '공구등'],
#  ['관제관련시스템'],
#  ['쇄목기', '각종식물질물질'],
#  ['레미콘트럭'],
#  ['전산프로그램'],
#  ['가위', '바늘', '실', '다리미', '자'],
#  ['와이어톱', '연마기'],
#  ['사무기기'],
#  ['카메라', '조명기', '레이저봉', '측정자'],
#  ['출동자동차', '무전기', '전복', '컴퓨터', '총'],
#  ['방적', '직물', '편모', '원단', '염색'],
#  ['증거수집', '보관물품', '엑셀'],
#  ['포토샵', '엑셀', '티비페인트'],
#  ['PC', '자파', '리눅스'],
#  ['열처리기', '열관', '장갑', '촉매관등'],
#  ['교사-한글', '파워포인트', '엑셀', '프레지등'],
#  ['운동기구', '맛사지용품'],
#  ['sopi'],
#  ['컴퓨터', '일러스트'],
#  ['컴퓨터', '필기도구'],
#  ['PC', '제품의설계도', '분석표'],
#  ['절단기', '제본기', '샌드페이퍼'],
#  ['편집프로그램'],
#  ['크레인', '안전모', '장갑'],
#  ['TRANSCAD', 'PC'],
#  ['무선통신기'],
#  ['엑셀', 'PC'],
#  ['쇄목기', '약품', '식물성물질', '폐지'],
#  ['노트북', '보고서', '더존'],
#  ['포토샵', '파워포인트'],
#  ['컴퓨터', 'MSofficeprogram'],
#  ['ppt', 'NEIS', '티칭'],
#  ['캐드', 'PC', '엑셀', 'MOS', '전화기', '토지측량기'],
#  ['컴퓨터', '테블릿PC'],
#  ['워드', '엑셀'],
#  ['다이어리', '스케줄표'],
#  ['지게차'],
#  ['지팡이', '카드', '링등'],
#  ['CAD', 'CAM', '현미경'],
#  ['드라이기', '가위', '빗'],
#  ['전기선', '펜치등'],
#  ['침', '진단기'],
#  ['PC', '일정표'],
#  ['컴퓨터', '솔리드웍스', 'ERP', 'CAD프로그램', '시뮬레이션소프트웨어'],
#  ['시뮬레이션프로그램', 'SPSS'],
#  ['CAD', '인디자인', '레빗'],
#  ['트럭'],
#  ['카스기계(구동프로그램)', '속기사용키보드'],
#  ['공구'],
#  ['크레인'],
#  ['구조설계도', 'PC'],
#  ['편직기', '가위'],
#  ['항공노선프로그램'],
#  ['도면', '드라이버', '렌치', '망치', '니퍼'],
#  ['구명복', '안전벨트', '산소마스크'],
#  ['트레이', '안전밸트', '면세품일체'],
#  ['포토샵', '포토스케이프', '파워디렉터', '카메라', '캠코더등'],
#  ['MES', 'ERP', '화학제품계측기', '전지시험기'],
#  ['주방조리기구'],
#  ['상담지', '자료'],
#  ['드라이버', '톱'],
#  ['절단기', '철사'],
#  ['공연복', '운동화'],
#  ['절단기', '칼', '육류용분쇄기'],
#  ['PC', '원고지', '팬'],
#  ['무전기', '마이크'],
#  ['컴퓨터', '토지측량기'],
#  ['책', '컴퓨터', '칠판', '분필등'],
#  ['목장갑'],
#  ['절단기', '나사'],
#  ['작업공구'],
#  ['시물레이션소프트웨어(Maxwell', 'CAD프로그램AutoCAD', 'SolidWorks)'],
#  ['시트지', '사다리'],
#  ['보육일지', '워드프로세서'],
#  ['전동드라이버', '테스터기', '전기인두', '노트북'],
#  ['컴퓨터', '자료등'],
#  ['전화기', '컴퓨터'],
#  ['산소호흡기', '심폐작동기', '응급차량'],
#  ['C언어', '자바'],
#  ['커피머신'],
#  ['무전기', '마이크', '운행일지'],
#  ['소품'],
#  ['비닐봉투'],
#  ['버스', '운행일지', '장갑'],
#  ['용접봉', '토치덤'],
#  ['앞치마'],
#  ['밀링기'],
#  ['발파기', '화학류'],
#  ['기계등'],
#  ['수공구'],
#  ['에프터이펙트', '프리미어'],
#  ['MS_WORD', 'EXCEL', 'POWERPOINT'],
#  ['거리측정레이저자'],
#  ['AutoCAD', '문서작성워드', '소음계', '진동계'],
#  ['기계공구'],
#  ['PC', '실험도구', '현미경', '확대경'],
#  ['CAD', 'MOS', '엑셀', 'PPT', '닥터파이프'],
#  ['Pc', 'MS프로그램', 'SAs'],
#  ['사다리', '복장'],
#  ['일러스트', '포토샵'],
#  ['리모컨', '단정한옷'],
#  ['msoffice', 'window', 'java'],
#  ['미용도구', '아이롱'],
#  ['컴퓨터', '오피스', '캐드'],
#  ['HTML', 'JAVA', 'XML', 'URML'],
#  ['PC', '빅데이터', '클라우드', '오픈소스', '프로그램언어'],
#  ['케드', '줄자', '다리미'],
#  ['전기인두', '테스터기'],
#  ['호이스트'],
#  ['정비스캐너'],
#  ['지휘봉', '악보'],
#  ['발효기'],
#  ['컴퓨터', '책'],
#  ['요리도구'],
#  ['망치', '드라이버'],
#  ['고객카드', '태블릿'],
#  ['문서작성', 'CAD', '대벗', '엑셀', '한글'],
#  ['앞치마', '머리수건등'],
#  ['내시경', '청진기'],
#  ['모자', '장갑손전등'],
#  ['테블릿PC', '노트북', '컴퓨터', '필기도구(펜', '노트', '샤프)'],
#  ['PC', '비쥬얼스튜디오'],
#  ['드라이버'],
#  ['프레스', '진단기', '벤딩기'],
#  ['서울시행정포털사이트'],
#  ['PC', '팜플렛'],
#  ['음료생산하는기계들'],
#  ['보호장구', 'PC', '엑셀', '프로세스시물레이션'],
#  ['용접기', '동력공구'],
#  ['문제집(교재)'],
#  ['Altium', '컴파일러'],
#  ['통계프로그램'],
#  ['마이크', '교재', '망원경'],
#  ['PC', '방송기기', '헤드셋'],
#  ['연마기', '망치', '끌'],
#  ['진료도구', '환자의무기록지', '주사', '약물'],
#  ['컴퓨터', '보존기록물'],
#  ['태블릿PC'],
#  ['염색약', '표백제', '장갑'],
#  ['나이스프로그램'],
#  ['다리미', '줄자', '가위'],
#  ['트렉터'],
#  ['공감프로램', 'SPSS', '언어프로그램', '의사소통프로그램'],
#  ['악기', '악보'],
#  ['오토캐드'],
#  ['접착제', '본뜨기틀', '절단기'],
#  ['안마기', '온열기계등'],
#  ['마이크', '악보'],
#  ['PC', '법관련서류', '법령집'],
#  ['안전관리'],
#  ['침대'],
#  ['PC', 'MSOfficeProgram'],
#  ['대본', '펜', '녹음장치'],
#  ['다이어리'],
#  ['필기도구'],
#  ['대본'],
#  ['컴퓨터', '키보드', '휴대폰', '필기도구'],
#  ['밀링기', '드릴링', '그라인딩'],
#  ['컴퓨터', '전화'],
#  ['법관련서적', '서류', '컴퓨터'],
#  ['압축기'],
#  ['트렉터', '경운기', '트럭'],
#  ['디브레인프로그램', 'PC', '전자문서'],
#  ['태블리PC', '책상', '메모지'],
#  ['1톤트럭', '바구니'],
#  ['요리기구', '위생복', '위생모', '나이프', '도마', '식단계획표'],
#  ['상권정보시스템'],
#  ['전자차트', 'EMR', 'OCS', 'PACS'],
#  ['재판사무시스템', '디지털회계프로그램'],
#  ['유니패스', 'CS자동선별검사시스템'],
#  ['공구', '기구'],
#  ['오토캐드', 'PC'],
#  ['CAD', 'pmis', '계측장비'],
#  ['충방전기', '카티아', '오토캐드'],
#  ['CO2피더기', '용접기', '절곡기'],
#  ['MSSQL', 'Editplus'],
#  ['각종분석기계', '컴퓨터'],
#  ['클라리넷'],
#  ['희곡대본'],
#  ['PC', '메모리디버거', '컴퓨터시스템OS', '응용소프트웨어툴'],
#  ['축구공', '축구화', '유니폼', '스타킹'],
#  ['컴퓨터', '회사재무제표', '주식'],
#  ['전동공구'],
#  ['컴퓨터', '캐드', '보호장구', '검지기', '측정기'],
#  ['전화기', '헤드셋'],
#  ['드라이버', '가위', '벤치'],
#  ['철솔', '용접장비', '도치팀', '용접봉', '작업지시서', '화공약품'],
#  ['미용도구(가위', '클리퍼', '드라이기)'],
#  ['볼펜', '탑승자명단', '카트'],
#  ['오토바이', '포스단말기'],
#  ['전자통관시스템'],
#  ['의사랑', '전기수술기', 'C-ARM', 'CT-GE'],
#  ['사출성형기', '장갑'],
#  ['실사프로그램', '도면', '이미지본드'],
#  ['컴퓨터', '보안프로그램(알랩)', '보호장구', '측정기', '검지기'],
#  ['모자', '장갑', '장화', '슬리퍼'],
#  ['PC', '프로젝트', '컴퓨터'],
#  ['사내프로그램', '엑셀', '각종미술도구등'],
#  ['PC', '상권정보시스템'],
#  ['AUTOCAD법령', '감리제도법'],
#  ['편집용컴퓨터프로그램'],
#  ['컴퓨터', '미술도구', '창작에활용할수있는사물'],
#  ['의료보험청구프로그램'],
#  ['헬레콥터', '보호안경', '헤드셋', '계측기'],
#  ['그라인더', '캐드', '각종기계장비'],
#  ['노트북', '컴퓨터부품'],
#  ['전동공구', '헬멧', '도면'],
#  ['항공장비', '정밀공구', '드라이버', '망치', '스패너', '수건'],
#  ['컴퓨터', '무역프로그램(실용장등)SAP', 'ERP'],
#  ['연장도구'],
#  ['플라스틱사출기'],
#  ['진료도구(혈액화학분석기', '경비내시경', '초음파)'],
#  ['PC', 'MSofficeprogram'],
#  ['각종계기판', '컴퓨터'],
#  ['CNUcare'],
#  ['pc', 'visualstudio', '이클립스', '컴퓨터시스템os'],
#  ['시설운영전산시스템'],
#  ['Pc', 'office', 'Excel'],
#  ['탈묵기', '쇄목기'],
#  ['환자차트EMR'],
#  ['드라이버', '계측기', '엑셀', '캐드'],
#  ['도장기', '도표'],
#  ['역사서적'],
#  ['자료', '컴퓨터', '종이', '연필', '볼펜'],
#  ['운동기구', '재활기구'],
#  ['컴퓨터', '기획서'],
#  ['용접기', '그라인더'],
#  ['마술상자'],
#  ['CAD', '스케치북', '포토샵', '일러스트레이터'],
#  ['마스크', '살포기'],
#  ['성경책'],
#  ['내비게이션', '장갑', '택시'],
#  ['모자', '장갑', '장화'],
#  ['포장기계'],
#  ['PC', '고서적'],
#  ['싱글페이서'],
#  ['PC', '실험도구', '위생복'],
#  ['프로툴프로그램'],
#  ['ERP', '실험도구'],
#  ['가위', '자', '원사'],
#  ['셋손', '장갑', '줄자'],
#  ['치과진료기구', '환자기록카드'],
#  ['PC', '재활치료기기'],
#  ['안전모', '보안경', '비계'],
#  ['진단기구(manilestrefraction',
#   'tonometer',
#   'slitlamp',
#   'Autorefraction등여러가지)',
#   '검사관련프로그램(OCT',
#   'optos등)'],
#  ['PC', '타블랫프로그램', '스케치업'],
#  ['도금장비들'],
#  ['ezspc(공정능력해석프로그램)', '전동드라이버', '파워미터', '절연저항계', '내전압시험기', '온도기록계등'],
#  ['실험기구', '엑셀'],
#  ['델파이', '파워벨더'],
#  ['킥스'],
#  ['매스매티카', '엑셀'],
#  ['게이지', '절곡기', '용접기', '리벳'],
#  ['유리칼', '코킹진', '경첩'],
#  ['엑셀', '일러스트', '포토샵'],
#  ['다양한공구들'],
#  ['제본기', '절단기'],
#  ['PC', '전화', '각종진단도구', '녹음기'],
#  ['이클립스', '비주얼스튜디오', 'JAVA'],
#  ['한글', '엑셀', '파워포인트'],
#  ['시방서', '용접기', '단면도', '견적서'],
#  ['침', '뜸'],
#  ['건축감리프로그램', '액셀', '건축오토캐드'],
#  ['몽키스패너', '용접기', '각종전동공구'],
#  ['피아노'],
#  ['에어공구', '미프트'],
#  ['세올행정시스템', '온나나시스템'],
#  ['파이프렌찌', '몽키', '드라이버'],
#  ['바둑', '바둑판'],
#  ['슈즈', '의상'],
#  ['무전기', '레이더모니터'],
#  ['리모컨', 'PC', '빅데이터', '대본'],
#  ['헤드셋', '캠', 'PC', '게임프로그램'],
#  ['MOS', '컴퓨터', '보안프로그램(만랩)실험분석잘비및자료', '측정기'],
#  ['브로셔', 'SPMS시스템'],
#  ['델파이', '비쥬얼베이직'],
#  ['흙손'],
#  ['튜너', '수리도구'],
#  ['해설교구재(루페', '돋보기)'],
#  ['온나라', '새옴', 'BIM'],
#  ['전기기구'],
#  ['건축관련프로그램', '케드'],
#  ['엔진동력계', '드라이버', '망치', '스페너'],
#  ['포토샵', '일러스트'],
#  ['PC', 'JAVA', 'C언어', '백신'],
#  ['PC', '고서적', '고지도', '외교문서', '국제조약'],
#  ['노트북', '명함', '카달로그', '계약서'],
#  ['설계프로그램', '3D캐드'],
#  ['워드', '회계프로그램', '전화기'],
#  ['솔리드웍스'],
#  ['한글', '엑셀', '인터넷'],
#  ['PC', '고지도', '역사관련자료들'],
#  ['PC', '옷감', '스케치북', '원단'],
#  ['한글', '엑셀', '파워포인트', 'CAD', '포토샵'],
#  ['ERP', '운송관리시스템'],
#  ['드라이버', '망치', '스패너'],
#  ['정비도구(드라이버)'],
#  ['십자가', '프로젝트', '성경책'],
#  ['가위', '드라이기'],
#  ['사람', '손', '전기기계'],
#  ['대폐공구'],
#  ['척사', '나사드라이버'],
#  ['교육자료', '파워포인트', '엑셀'],
#  ['PC', '녹음프로그램', '대본', '마이크'],
#  ['법전', '판례검색프로그램', '법령문'],
#  ['안전화', '장갑등'],
#  ['더존프로그램', '아이패이'],
#  ['사복프로그램', '컴퓨터'],
#  ['금속', '전화', '컴퓨터'],
#  ['작곡용지', '녹음'],
#  ['나이스프로그램', '진단지', '워드', '엑셀'],
#  ['비디오', '오디오장비', '현수막', '행사용품', 'PC', '마이크', 'PhotoShop'],
#  ['PASS', 'OLS컴퓨터', 'EMR(전자chart)'],
#  ['조립부품공정도'],
#  ['컴퓨터', '포스기계', '책상'],
#  ['손차', '리어카'],
#  ['파워포인트', '엑셀'],
#  ['볼펜', '영주증'],
#  ['시터S', '교과서'],
#  ['장갑', '곡갱이', '경운기', '호미'],
#  ['PC', '법무서류'],
#  ['더존'],
#  ['재봉틀'],
#  ['실험기구'],
#  ['캐드', '포토샵', '도면'],
#  ['미싱', '초크', '줄자', '명세서', '원단', '단추', '절단기', '필기도구', 'PC'],
#  ['포스', '지폐', '동전', '봉투'],
#  ['파워포인트', '가위', '자'],
#  ['카트'],
#  ['장갑', '보호구'],
#  ['카스기계', '녹음기'],
#  ['화물운송목록표'],
#  ['3d시뮬레이션', '삼바리', '건축캐드프로그램'],
#  ['RF계측기및시험툴'],
#  ['컴퓨터', '메모지', '볼펜'],
#  ['전동공구', '드라이버', '정비복및장갑', '탈착기', '측정기', '차량및전화기'],
#  ['PC', '보호장구', '측정기'],
#  ['펜', '포토샵', '그래픽디자인', '컴퓨터'],
#  ['PC', '강의교제'],
#  ['언어프로그램', '녹음기', '상담일자관리', 'SPSS', 'MSoffice'],
#  ['PC', '직업관련자료(고용안전정보망)'],
#  ['심리검사장비(MMPI', 'TCI', '로샤등)'],
#  ['한글', '포토샵', '엑셀'],
#  ['컴퓨터', '스마트폰포토샵', '일러스트', '블러그'],
#  ['애완동물용그릇'],
#  ['마야'],
#  ['업무포털시스템'],
#  ['다로카드', '팥'],
#  ['전력계통해석프로그램PSS/E', '운영시스템(SCsde', 'Has등)'],
#  ['유니트게임엔지니어', '안드로이드'],
#  ['마분지', '판', '기타보조물'],
#  ['경운기', '농기구'],
#  ['피아노', '교재'],
#  ['계약서', '컴퓨터', '제품브로셔(팜플렛)', 'MSofficeprogram'],
#  ['축구화', '축구공', '유니폼', '스타킹', '정강이보호대'],
#  ['드라이버', '가위'],
#  ['절', '불경', '목탁', '염주'],
#  ['캐드', '엑셀', '온도센서'],
#  ['컴퓨터', '전화기등'],
#  ['후레시', '호루라기'],
#  ['태드', '스케치업', '포토샵'],
#  ['그림'],
#  ['파이널컷프로', '에프터이펙트'],
#  ['대리석', '화강석', '수치계', '절단기'],
#  ['화약류', '각종기구(뇌관', '도화선', '장약등)'],
#  ['앞치마', '국자', '냄비'],
#  ['컴퓨터', '측량기기'],
#  ['PC', '계측기'],
#  ['운송프로그램', '워드', '엑셀'],
#  ['농구공', '농구화', '운동복'],
#  ['PC', '이클립스', '비주얼스튜디오'],
#  ['마술도구'],
#  ['PC', '내부감사프로그램(SAT)'],
#  ['각종공구', '롤러등'],
#  ['스페너', '망치', '드라이버'],
#  ['컴퓨터', '노트북'],
#  ['php', '자바'],
#  ['PC', '약정서'],
#  ['엑셀', '파워포인트', '측정계', '점도계', '온도계', '스프레이건'],
#  ['PC', '전화'],
#  ['편집프로그램', '포토샵', '일러스트'],
#  ['PC', '자바', '리눅스', '유닉스'],
#  ['전기공구', '드라이버'],
#  ['연마기', '끌', '정', '망치'],
#  ['환자기록카드', '치과치료기구'],
#  ['3D프로그램(Maya', '3DMax', 'Clae', 'a4D', 'Zdrush)등'],
#  ['컴퓨터', '운동기구'],
#  ['자동조립설비'],
#  ['한글', '워드', '엑셀'],
#  ['로스팅기계', '추출기'],
#  ['문서관리프로그램(ms-office', '한글)'],
#  ['원고지', '연필', '메모지'],
#  ['PC', '엑셀', '한글', '빔프로젝트'],
#  ['섬유제조장치', '동물털', '합성섬유', '식물섬유'],
#  ['재단사', '가위', '칼', '초크', '도면'],
#  ['전압전류계', '드라이버등'],
#  ['코스닥컴퓨터'],
#  ['스크루드라이버', '나사드라이버'],
#  ['실험도구및약품'],
#  ['엑셀', 'PPT', 'UX/UI'],
#  ['PC', 'EXCEL'],
#  ['금융프로그램'],
#  ['심리검사장비(MMPI', 'TCI)'],
#  ['방진마스크', '안전모'],
#  ['철강제품도포용열침책장비', '전기도금장비', '아연도금봉', '히터'],
#  ['쪽가위'],
#  ['감지기', '보호장구'],
#  ['전기충전기', '계측기', '발전기'],
#  ['컴퓨터', '태블릿'],
#  ['택시'],
#  ['혈압계'],
#  ['안전모'],
#  ['용접기', '스패너'],
#  ['자바', '프로그래밍언어'],
#  ['바코드스캐너', '금전등록기'],
#  ['설계도', '체크리스트'],
#  ['광파기'],
#  ['케이블'],
#  ['차량관제시스템', '엑셀', '워드'],
#  ['Metlab', 'Origin', 'Silvaco등'],
#  ['PPT', '한글', '엑셀'],
#  ['컴퓨터', '혈중알콜측정기'],
#  ['대걸레', '니퍼', '풀', '계측기'],
#  ['피아노', '기타'],
#  ['열처리기계', '현미경', '단소황분석시'],
#  ['전기배선공구', '전기시스템부품', '측정기', '전기계측기', 'PC', 'SAP'],
#  ['수놀이기구', '몬테소리'],
#  ['PC', '소프트웨어(가상현실)'],
#  ['PC', 'ez-balance', '시그마플롯', '모델링프로그램'],
#  ['엑셀', '워드', '종이', '펜'],
#  ['컴퓨터', '수업교재', '엑셀'],
#  ['디자이너-포토샵', '일러스트프로그램/MAC컴퓨터'],
#  ['컴퓨터', '엑셀프로그램'],
#  ['경운기', '트랙터', '호미', '낫'],
#  ['기관차', '무전기', '제복'],
#  ['식단', '도마', '칼', '위생복'],
#  ['호루라기', '안전봉등'],
#  ['컴퓨터악보', '건반', '피아노', '기타'],
#  ['미싱', '가위', '줄자'],
#  ['마이크'],
#  ['3Dmax', 'Zbush'],
#  ['안전모', '안전화', '후레쉬(렌턴)'],
#  ['볼펜', '놀이시설관련도구'],
#  ['관련서적', 'PC'],
#  ['컴퓨터', '볼펜등'],
#  ['의상', '잡화', '소품'],
#  ['제안서', 'PC', '계약서'],
#  ['연삭기', '정', '망치'],
#  ['랩뷰', '마이컴', 'C언어'],
#  ['코스맵', '골프카'],
#  ['컴퓨터', 'PPT', '엑셀'],
#  ['PC', '스케치업', '인디자인'],
#  ['KPIS', '한국가스공사배관망정보시스템'],
#  ['캐드', 'PC'],
#  ['MSS', '실리콘', '접착제'],
#  ['설계도면', 'PC', 'MQC', '고려전산'],
#  ['MQC고려전산'],
#  ['금전등록기', '바코드스캐너'],
#  ['절단기', '절곡기', '프레스기'],
#  ['PC', '자바', '리눅스'],
#  ['업무일지', '장갑'],
#  ['유리가공장비', '강회유리기계'],
#  ['의사랑'],
#  ['컴퓨터', 'AUTOCAD', '일러스트레이터'],
#  ['더존', '엑셀', 'PC', '전화기'],
#  ['프레스', '선반'],
#  ['엑셀', '실험분석자료', 'UTH', 'SEM', '화학물질'],
#  ['컴퓨터', '한글', '오피스', '노트북'],
#  ['가위', '원단', '직각자'],
#  ['PC', 'SPSS', '엑셀'],
#  ['자연물'],
#  ['워드', '파워포인트', '포토샵'],
#  ['녹음기'],
#  ['달력', '일정표', 'PC'],
#  ['각종교재'],
#  ['분석프로그램', '분석기기', '소음측정기', 'icp'],
#  ['교재', '컴퓨터', '교구', '필기구'],
#  ['CAD', '열처리기계', '탄소황분석기'],
#  ['유압측정게', '엔진동력계', '드라이버', '망치', '스케너'],
#  ['Microsoft(PPT', '엑셀)', '한글'],
#  ['국가통합형사사법정보시스템'],
#  ['정보프로그램', '감리자동화도구'],
#  ['교과서', 'PC', '칠판'],
#  ['PC', '휴대폰'],
#  ['pc', '책'],
#  ['도로모토프로그램', '전산분석프로그램', '트랜스캐드'],
#  ['수공구', '목공기계들'],
#  ['편집프로그램', '일러스트', '인디자인'],
#  ['재단기', '원단', '가위', '자'],
#  ['압연기', '프레스기'],
#  ['통경대', '직기', '통령바늘'],
#  ['화이트보드', '수성펜', '참고서'],
#  ['인사업무프로그램'],
#  ['하수처리기계', '측정기'],
#  ['자동차', '수리연장/기계', '오일', '기타등등'],
#  ['컴퓨터', '오토캐드', '워드', '엑셀'],
#  ['가위'],
#  ['일러스트레이터', '포토샵'],
#  ['책'],
#  ['각종공구'],
#  ['관련DB프로그램', '배양기', '실험도구'],
#  ['PC', 'EXCEL', '캐드', '포토샵'],
#  ['나이스'],
#  ['샘플룩', 'MSofficeprogram', 'PC', '포토샵', '어도비프로그램', '캐드'],
#  ['통계분석프로그램', 'Delphi', 'C언어'],
#  ['MSOffice'],
#  ['스페너', '드라이버', '망치'],
#  ['이클립스', '와이어샤크'],
#  ['PC', '오리진', '수치해석프로그램'],
#  ['인터콤', '수공구'],
#  ['줄자', '초크', '연필', '송곳', '재봉틀', '실', '바늘등'],
#  ['계랑부자', '로프', '배', '녹끝'],
#  ['바구니', '포스기', '유니폼'],
#  ['파이썬', 'PC', 'SPSS', 'DYmate'],
#  ['자', '커터칼', '방수비'],
#  ['오리진', 'PC', '실험장비'],
#  ['심리검사도구', '심리치료도구등'],
#  ['수산자원조사용품', '용출기등'],
#  ['갈고리'],
#  ['장갑', '앞치마'],
#  ['침'],
#  ['OA프로그램'],
#  ['카메라', '대체측장비', 'PC'],
#  ['이양기', '트렉터', '경운기등등'],
#  ['바둑알', '바둑판'],
#  ['PC', '펜', '국어사전'],
#  ['엑셀', '통계프로그램'],
#  ['장갑', '마스크', '장화'],
#  ['전동드라이버', '컴퓨터'],
#  ['퍼터샵', '일러스트'],
#  ['도금기', '코팅기', '접착제'],
#  ['키보드', '컴퓨터'],
#  ['안전화', '안전모', '장갑', '마스크'],
#  ['콘데서관', '송전철탑', '공기예열관'],
#  ['노트북', '펜', '메모지'],
#  ['팜스탬프', '카티아', '디폼'],
#  ['전기공구'],
#  ['CAD', '맥'],
#  ['가위', '자'],
#  ['ENT세이버', '벤츄레이터', '청진기', '마취기', '현미경비경'],
#  ['PDA'],
#  ['충전지', '소형발전기', '밧데리'],
#  ['엑셀', '워드', '측정기'],
#  ['PC', '전화기'],
#  ['제단도구', '초크', '바늘', '칼', '가위', '다리미', '제단'],
#  ['전자결재시스템'],
#  ['배선도', '공구set', '작업지시서'],
#  ['찜질기', '숙뜸이', '핫팩', '물리치료기기'],
#  ['영산신호측정기'],
#  ['현미경', '분광기', '편광기'],
#  ['주방기구(칼', '도마)'],
#  ['컴퓨터등'],
#  ['pc', '장난감', '대여관리프로그램'],
#  ['4.5노트북', '곡괭이', '짚', '삽', '전기톱'],
#  ['테스터기', '저울', '호모믹서', '측정기', 'MSoffice프로그램'],
#  ['보도블럭등'],
#  ['업무포털(NEIS)'],
#  ['PC', '운송일정표'],
#  ['실험도구'],
#  ['축구코치-볼', '마커', '몬', '조끼'],
#  ['컴퓨터', '실험기기'],
#  ['워드', '엑셀', '파워포인트'],
#  ['교재', '필기구', '컴퓨터'],
#  ['분석시험도구'],
#  ['페인트', '에나멜', '락카', '스프레이', '자동분부기'],
#  ['Oracle', 'Toad'],
#  ['초음파진단기'],
#  ['그래픽', '포토샵'],
#  ['플래쉬', '레이져'],
#  ['큐베이스', '프로툴', 'PC'],
#  ['우규', '기저귀', '젖병', '인형놀이'],
#  ['엽연초', '건조기', '절단기'],
#  ['포크레인', '트럭'],
#  ['붓', '흙손', '목재졸대', '회반죽바름', '회반죽이떨어지는것을방지하는상실'],
#  ['음악', 'CD플레이', '무용복'],
#  ['승복', '법전', '목탁'],
#  ['대본', '무대의상', '소품', '변장도구', '마이크'],
#  ['PC', '국채매입프로그램'],
#  ['줄자', '카메라', '측량기', '계산기'],
#  ['대본', '의상', '분장'],
#  ['골레이트장비'],
#  ['공구함', '토치'],
#  ['참고문헌', '엑셀'],
#  ['소형마이크', '의상'],
#  ['컴퓨터', '태권도복', '프로그램', '기본동작', '겨루기등등'],
#  ['엑셀', '한글', '파워포인트'],
#  ['청진기', '혈압기'],
#  ['컴퓨터', 'Adobe계열프로그램', '다빈치', 'C4D'],
#  ['현미경', '컴퓨터'],
#  ['PC', '학습지', '펜'],
#  ['전산시스템', '처방전', '조제법'],
#  ['나무'],
#  ['ERP프로그램', '항공정비공구'],
#  ['게임프로그램', 'PC', '게이밍키보드'],
#  ['컴퓨터', '오피스(M/S)', '녹음기', '한글', '워드', '속기전용프로그램'],
#  ['드릴', '온도센서', '캐드X'],
#  ['아이롱', '드라이기', '파머약', '염색약'],
#  ['JAVA', '파워포인트'],
#  ['LC', 'LC-MS', 'GC', 'GC-MS', 'ICP-MS', '질소농축기', '원심분리기', '피펫등'],
#  ['SPSS', 'Amos'],
#  ['마사지베드'],
#  ['깃발'],
#  ['미싱', '프레스', '펀칭기.컴퓨터'],
#  ['컴퓨터', 'ppt'],
#  ['포토샵', '일러스트', '인디자인'],
#  ['PC', '보험약관프로그램'],
#  ['의료정보시스템'],
#  ['가공하는기기', '전고기', '가공기'],
#  ['PC로보고서', '실험도구', '화학물질', '실험분석자료'],
#  ['PC', 'MSSQL', '일러스트레이터'],
#  ['접지저항제', '후크메타', '메거'],
#  ['클리패', '아이롱', '직떰기'],
#  ['멸균기', '초음파치료기', '레이저치료기', '마취기', '환자기록DB'],
#  ['영상편집프로그램', '편집장비'],
#  ['절단기', '궐련지', '담배잎'],
#  ['필기도구', '전화기'],
#  ['믹싱콘솔', '마이크', '파워앰프', '등'],
#  ['말'],
#  ['kovisStayoo'],
#  ['대본', '마이크', '소품'],
#  ['PC', '엑셀', '통계프로그램'],
#  ['pc', '열측정기'],
#  ['벽돌', '보도블럭등'],
#  ['재단도구', '포토샵', '곡자'],
#  ['앞치마.교재및교구'],
#  ['청진기', 'X레이등'],
#  ['Excel', 'Word', 'PhotoShop'],
#  ['마스크'],
#  ['엑셀', '파워포인트', '책'],
#  ['딱히없다'],
#  ['AFTEREFCTS', 'Photoshop', 'Ai(Adobeprogram)', '다빈치'],
#  ['컴퓨터', '무역통관(수출입)프로그램', 'ERP', 'SAP'],
#  ['피아노', '악보', 'PC'],
#  ['응급구조기구', '구급차', '응급처치용약품'],
#  ['영업시스템(DCS', 'PLC)'],
#  ['PC', '엑셀', 'MS프로그램'],
#  ['PC', '대본'],
#  ['도수변환프로그램', '안경태', '콘택트렌즈', '도수측정기계'],
#  ['젖병', '트랙터'],
#  ['PC', '엑셀', '워드'],
#  ['기계정비공구류', '설비제어프로그램'],
#  ['마야넥스', '티버페인트', '포토샵'],
#  ['EMR'],
#  ['컴퓨터', '엑셀', '워드', '파워포인트'],
#  ['전공서적', '교육참고자료'],
#  ['캐드', 'PC', '도면'],
#  ['컴퓨터그래픽', '3D캐드'],
#  ['냄비', '국자'],
#  ['컴퓨터', '계산기', '필기구', '유통프로그램', '포스시스템'],
#  ['컴퓨터', '필기도구', '기타'],
#  ['엑셀', '캐드', '한글', '파워포인트'],
#  ['분석기기에따른각각의프로그램'],
#  ['의무기록프로그램', 'PC', '진료기구', 'MSofficeprogram'],
#  ['파워포인트', '전공서적'],
#  ['각종운동기구'],
#  ['카메라', '특수장비'],
#  ['교재', '녹음기'],
#  ['직기', '통령바늘'],
#  ['포토샵', '인디자인'],
#  ['태드', 'ESS시스템', '컴퓨터'],
#  ['소독기'],
#  ['컴퓨터', '필기도구', '의료도구'],
#  ['노트북', '명함', 'PC', '의약설명서'],
#  ['축구공', '아대', '축구화', '유니폼'],
#  ['MS오피스', '일러스트', '스케치업', '포토샵'],
#  ['PC', '캐드프로그램', '계측기'],
#  ['장갑', '마스크'],
#  ['검퓨터', '엑셀'],
#  ['보안시험도구', 'DB모델링툴'],
#  ['랩뷰', '캐드'],
#  ['CNUcare', '전자챠트'],
#  ['교재', 'PC'],
#  ['장갑', '특수차'],
#  ['한글오피스'],
#  ['PCBCAD', '논리제어기'],
#  ['주식거래프로그램'],
#  ['PC', 'T자', '옷감', '연필', '스케치북'],
#  ['사료', '축사'],
#  ['핸드피스', '스켈일러', '포셋', '청진기'],
#  ['노트북', '필기도구', 'MSofficeprogram'],
#  ['국회일정관리표', '각종통계자료', '메모지', '워드'],
#  ['PC', '강의시간표'],
#  ['무대설계도', '캐드', '컴퓨터'],
#  ['테스트기레가전기충전기'],
#  ['맥킨토시', '인디자인', '캐드'],
#  ['직무프로그램'],
#  ['편광기', '현미경', '분광기', '비중액'],
#  ['엑셀', '파워포인트', 'SPSS'],
#  ['화학교수', '연구용소프트웨어'],
#  ['재료', '기계등'],
#  ['명함', '샘플', '노트북', '계약서'],
#  ['박스'],
#  ['비료살모기', '방제기', '사다리', '장갑'],
#  ['장비', '약품(소독액', '해충액)'],
#  ['PC', '홍진데이터', '노선절류'],
#  ['판촉물', '청약서', '가입설계서'],
#  ['노트북', '자동차'],
#  ['미술도구'],
#  ['의료기기'],
#  ['T자'],
#  ['각종분석기계들', '컴퓨터'],
#  ['객실열쇠', '청소도구'],
#  ['노트북'],
#  ['축구공', '유니폼', '축구화'],
#  ['성격책'],
#  ['PPT', 'Acare등'],
#  ['OPCserver', 'CAD', '일러스트'],
#  ['인쇄기', '잉크', '용지'],
#  ['PC', '이클립스', '언어프로그램', '스위그'],
#  ['보완대체의사소통어플(AAC)'],
#  ['청진기'],
#  ['컴퓨터', '워드', '파워포인트'],
#  ['스캐너', '전동공구'],
#  ['점치는도구'],
#  ['수리도구(드라이버)'],
#  ['창고자료표', '기획안', '워드프로세서'],
#  ['PC', '교재', '교구'],
#  ['혈압기', '체온기', '주사기', '약통'],
#  ['홍진데이터', '전기충전기', '캐드도면'],
#  ['나이스시스템'],
#  ['로봇시술'],
#  ['CAD', 'BIM'],
#  ['도면작성프로그램(오토캐드)', '3D렌더링프로그램(라이노', '스케치업)'],
#  ['통제시스템', '공정관리시스템'],
#  ['교재.', '컴퓨터', '관련교구'],
#  ['컨베이어밸트'],
#  ['ERP', '엑셀'],
#  ['PC(감사프로그램)', '엑셀', 'SAT', 'ERP'],
#  ['PC', '비주얼스튜디로', '일러스트'],
#  ['미술도구', '엑셀', '파워포인트'],
#  ['모니터'],
#  ['교재', '펜', '태블릿PC'],
#  ['CAD', '파워포인트', '굴삭기', '쌤스프로그램'],
#  ['교재', '교구'],
#  ['컴퓨터', '인트라넷', '개인화기'],
#  ['분집흡입화', '종합검측사', '연마밀링화'],
#  ['마이크로소프트웨어프로그램', 'CAD', 'SPS'],
#  ['PC', 'AUTOCAD', '시뮬레이션tool'],
#  ['호루라기', '깃발'],
#  ['펜', '종이'],
#  ['경운기', '이앙기'],
#  ['녹음기', '큐베이스', '베가스'],
#  ['판재', '석고'],
#  ['PC', '교과서'],
#  ['종이', '풀', '가위'],
#  ['이클립스', '오라클', '자바'],
#  ['주사기', '핀셋', '청진기', '가위'],
#  ['볼펜', '면세품판매를위한카트'],
#  ['일러스트', '포토샵', '코렐드로우', '인디자인', 'Mac', '오피스', '한글'],
#  ['업무용HP', '컴퓨터', '계산기'],
#  ['드릴', '드라이버', '나사'],
#  ['각종수공구및동력기계'],
#  ['쵸크', '줄자', '가위'],
#  ['마이크', '대본', '공연복'],
#  ['플래쉬', '무비메이커'],
#  ['호루라기', '유니폼', '카드', '안전보호복'],
#  ['현미경', '식약청검사프로그램', '비커', '피펫', '플라스크'],
#  ['토크렌치', '글루엔트', '자동드라이버'],
#  ['주사'],
#  ['PC', '포토샵', 'MS오피스'],
#  ['엑셀'],
#  ['PC', 'SPSS', 'SAS', '경제적통계자료파일'],
#  ['쉐이커', '바스푼', '믹싱글라스', '스트레이너'],
#  ['PC', '계산기', '장부'],
#  ['에듀나비', '엑셀', 'ppt'],
#  ['손전등', '모자'],
#  ['오피스(MS)', '포토샵', '3DMAX'],
#  ['사료'],
#  ['항공교통관제사-항공정보프로그램(FDT', 'FOLS)'],
#  ['PC', '수갑'],
#  ['장애분석Tool', 'Java', 'wfc'],
#  ['시방석설계도면', '캐드'],
#  ['테블릿', '학습교재', '펜', '색연필'],
#  ...]

# %%
tool = sum(tool,[])
print(tool)
# Out:
# ['없다', '매타기', '드라이버', '가위', 'CAD', '건축설계표', '오토캐드', '파이프', '보일러', '토탈스테이션', 'SZP', '캐드', '엑셀', '건축도면', '볼펜', '컴퓨터', '볼펜', '퍼티', '프라이머써페이스', '코라스틱프라이머', '관제관련시스템(FDT', 'FOLS)', '가스충전기', '위험물취급메뉴얼', '검지기', '측정기', '한글', '관세총관시스템', '국회업무망', 'PC', 'EXCEL', 'PPt', '없음', '드림위버', '포토샵', '일러스트', '정비용공구(드라이버', '측정장비등등)', 'CDW', '웹사이트관리CMSIT프로그램(Adobe', 'IBM등)', '웹사이트데이터분석프로그램(GoogleAnglytics등)', '석고모형', '보철', '금', '은', '마스크', '보안경', '컴프레셔', '포토샵', '일러스트', '에프터이펙트등그래픽툴다수', '젖병', '카메라', '미용도구', '약품', '컴퓨터', '칼', '도마', 'NC선반', 'MCT', '프리미어', '에디우스', '3D맥스', '에팩', '기중기', '해머', '도라이버', 'mos', 'cad', '테스터기', '그림책', '장난감', '악기', '그림도구', '앞치마', '절단기', '절곡기', '곡괭이', '비닐', '삽등', '표준유물관리시스템', 'PC', '장갑', '문화재관리프로그램', '현미경', '핀셋', '도마', '칼', '삽', '괭이', '린치', '톱', '손수레', '삽', '트럭', '사육프로그램', '바늘', '실', '가위', '재봉틀', '다리미', '튜너', '드라이버', '스패너', '경운기', '칼', '도마', '위생복', '전동드라이버', '스패너', '벤치', '크링', '니퍼', '신호측정기', '아이롱', '용접기', '도면', '접수프로그램(네오소프트)', '소독도구(자외선소독기', '오토클램', '자불소독기)', '처치도구시저', '포셉)', 'MAC', 'CAD', '증권사별HTS', '빅스', '아이트레이더', '퀀티와이즈', 'MSoffice', '농기계들', '공구셋트', '교제', '놀이도구들', '에프터이펙트', '앞치마', '고무장갑', '수첩', '볼펜', '통신장비', '레더모니터', '복권', '로스팅기계', '저울', '칼', '도마', '쇄목기', '탈묵기', '볼펜', '카드', '화물차포크레인', '설계캐드프로그램', '전자축전기제조기', '농기계들', '경운기', '악보', '컴퓨터', '엑셀', '장갑', '화학증착기', '펜', '만년필', '잉크', 'HD연필', '스케치북', '엑셀', '퀀티와이즈', '블룸버그', 'HTS', '팩', '금융개발프로그램', '오토바이등비닐봉투', 'PC', '대본', '펜', '장소', '유아관련용품(유모차', '아기띠', '젖병)', '막대', '관', '봉', '스위치', '자동절연스트리퍼', '절연뺏치', '전동드라이버', '계측기', '프로젝트', '스케너', '압착탈수기', '건조기', '컴퓨터', '주사', '챠트지', '환자내역프로그램', '홈페이지', '펜하고잉크', '연필', '수리도구', '전동드라이버', '각종실험장비', '클렘벤치(무균상)', '안큐베이터', '안전화', '안전모', '클링', '드라이버', '벤치', '엑셀', '파워포인트', '치위생사', '스켈링', '글리피', '스패너', '용접기', '성형기', '재단기', '컴퓨터', '금융관리프로그램', '컴퓨터', '오피스(마이크로소프트)신용분석프로그램', '트레일러', '캐드', '도면', '공구', '측정기', '유니패스', '항공기', '데오드라이드', '측량도구', '레벨', '도면', '공구들', '스페너임펙트', '저존', '이크레더블', '심리검사(MMPI-2', 'SCT)', 'PC', '고서적', '학술연구자료', '국제조약', '각종조리기구', '체온계등', '컴퓨터', '자바', '이클립스등게임프로그램툴', '사출기', 'NEIS업무포털', '법전', '워드', '엑셀', '파워포인트', '캠퍼스', '마이크로미터', '조리사-조리도구(칼', '도마', '오븐', '전자레인지', 'Pot)', '지게차', '작업일지', '심리검사장비', 'PC', '엑셀', '제도용잉크', '밀리펜', '스케치북', '색연필', '위생복', '장화', '장갑', '모자등', '엑셀', 'PC', 'ERP시스템', 'CAD', '포토샵', '일러스트레이더', '도면', '튜닝해머', '2D/3D프로그램', '넥스', '마야', '프리미어', '맥등', '레이더모니터', '노선프로그램', '엑셀', '한글', 'CAD', '카메라', '딥(시소)', '달리(이동차)', '드론', 'SPSS', '실험도구', '헬멧', '안전화', '도면', '화장품', '팩', '전기기구', '각질제거기', '삽', '장갑', '곡갱이', '가위', '컴퓨터', '외국어(일본어)회화프로그램', 'MSofficeprogram', 'MS오피스', '이클립스', '펌웨어개발프로그램', '무전기', 'PC', 'Mes', 'ERP', 'Msoffice', '컴퓨터', '엑셀', '한글', '포토샵', '컴퓨터', '청진기', '고객챠트', '엑셀', '트레이딩시스템', '수갑', '가스총', '곤봉', '무전기', '검사장비', '심폐소생작동기', '구급차', '응급간이침대', '산소호흡기', '필기도구', '컴퓨터', '학사일정표', '교재', '도구(교구)', '노트북', '테블릿PC', '컴퓨터', '조미료', '조리기구', '위생복', '위생모', '행정온나라시스템', '줄자', '시멘트', '줄자', '도면', '휠체어', '자세유지보장구', '카메라', '송신장비', '병원홈페이지', '진료내역서증', '펜', '악보', '피아노등', '컴퓨터', '보험증권', '보험상품', '코팅기', '접착제', '도금기', '부식방지화학용품', '컴퓨터', '학습교재', '소품', '의상', '컴퓨터', '전화기', '화장품', '소품', '벽돌', '콘크리트블록', '경운기', '트랙트', '이양기등', '엑셀한글', 'X로이스', '오토캐드', '일러스트', 'ppt', 'ecotect등', '연마제', '연마기', '엑셀', '처방전', '포사케이트', 'PC', '엑셀', '미술치료사-미술도구', '금융관련프로그램', '엑셀', '응급차량', '산소호흡기', '심폐작동기', 'HTS', '오피스프로그램', '주방도구', '시험장비들', '공구세트', '법전', '판례문', '판결봉', '선서문', '필기도구', '교재', '기타교구', '교과서', '씨앗', '비료', '호미등', '침대', '크림', '수건', '맛사지기구등', '지휘봉', '가위', '미싱', '실', '자', '작업다이', '전기톱', '가위', '상품분석데이터프로그램', '삼품리스크프로그램', '컴퓨터', '자바', '이클립스', '재봉틀', '가위', '줄자', '트레이딩시스템', '엑셀', '드라이버', '공구', '부황', '침', 'CAD', '도면', '마스크', '장갑', 'ppt', '티칭', '에듀나비', 'ERP', '멀티채널측정기', '컴파일러', '파쇄기', '오피스프로그램', '블랙박스', '카드결제기', '머신', '그라인더', '로스팅기', '슈캐드', '솔리드윅스', 'AutoCAD', 'SPSS', '포토샵', '일러스트', '플래시', '플렉스', '건조기', '증류기', '혼합기', 'PC', '클라우드(에버노트', 'onedrive)', '빨대', '휴지통', '커피머신', '냉장고', '식기류', '가스', '가판대', '스피커', 'PC', '주방도구(냄비', '후라이팬등)', '계량기', '가위', '클리퍼', 'SPSS', 'JAVA', 'C#', '2.5톤트럭', '전지가위', '장갑', '린치', '정밀공구', '스캐너', '렌치', '드라이버등등', '네비게이션', '굴기계', '바늘', '실', '원단', '패턴', '컴퓨터', '전화', '더존', '고적리스트', '사 ...

# %%
tool = pd.DataFrame(tool)

# %%
tool[3093:3097]
# Out:
# ['트위져보석용타워', '아령외역기', '볼', '증권분석자료']

# %%
def remove_space(text:str):
  return text.replace(' ', "")
tool = tool[0].map(remove_space)
tool
# Out:
# 0                 없다
# 1                매타기
# 2               드라이버
# 3                 가위
# 4                CAD
#             ...
# 18175           일러스트
# 18176        AUTOCAD
# 18177          CATIA
# 18178    전문특수정비도구(툴)
# 18179        차량관리시스템
# Name: 0, Length: 18180, dtype: object

# %%
tool = tool.unique()

# %%
tool = tool.tolist()

# %%
know2017['bq31'].iloc[1]
# Out:
# '매타기,드라이버,가위,CAD'

# %%
my_dict = {}
for i in range(len(tool)):
  my_dict[tool[i]] = i

# %%
#know2017['bq31'].iloc[2]/

def text_to_list(text:str):
  return list(text.split(','))

know2017['bq31'] = know2017['bq31'].map(text_to_list)

# %%
know2017['bq31'].iloc[2][0]
# Out:
# '건축설계표'

# %%
def tool_to_label(tools:list):
  result = []
  for tool in tools:
    if tool in my_dict:
      result.append(my_dict[tool])
    else :
      result.append(0)
  return result

know2017['label1'] = know2017['bq31'].map(tool_to_label)

# %%
know2017
# Out:
#        idx  aq1_1 aq1_2  aq2_1  ... bq41_2  bq41_3 knowcode             label1
# 0        0      3     3      3  ...           2200   825101                [0]
# 1        1      4     5      4  ...           2400   140204       [1, 2, 3, 4]
# 2        2      3     4      3  ...           2400   140204       [5, 6, 7, 8]
# 3        3      3     3      3  ...           3500   140601            [9, 10]
# 4        4      4     5      3  ...           2500   140204       [11, 12, 13]
# ...    ...    ...   ...    ...  ...    ...     ...      ...                ...
# 9481  9481      3     5      2  ...           1800   411301  [25, 446, 33, 34]
# 9482  9482      5     5      5  ...           3000   151105  [998, 1397, 6370]
# 9483  9483      3     3      4  ...           1500   701101        [2134, 731]
# 9484  9484      3     5      3  ...           2500    25402               [15]
# 9485  9485      3     4      3  ...           3700    15201             [6371]
#
# [9486 rows x 157 columns]

# %% [markdown]
# ## 2018 데이터 라벨 인코딩

# %%
know2018 = know_train[1]
know2018
# Out:
#         idx  cq1  cq2  cq3  cq4  ...  bq40  bq41_1  bq41_2  bq41_3  knowcode
# 0      9486    5    3    4    2  ...    42    3800    3400            306301
# 1      9487    4    3    4    4  ...    40    2300    1800            133204
# 2      9488    4    1    5    3  ...  30.0                    3000    702502
# 3      9489    4    3    4    4  ...    40    3350    2750            121201
# 4      9490    3    2    3    1  ...    40    2500    2300            306301
# ...     ...  ...  ...  ...  ...  ...   ...     ...     ...     ...       ...
# 9067  18564    5    5    5    2  ...    60                    2000    303002
# 9068  18565    5    5    5    3  ...  52.0                    5000    615203
# 9069  18566    4    4    4    3  ...    38                    9000    301106
# 9070  18567    5    2    3    2  ...    56                    6500    301112
# 9071  18568    5    4    5    4  ...    40    4200    2800            133101
#
# [9072 rows x 141 columns]

# %%
know_train[3]
# Out:
#         idx  saq1_1 saq1_2  saq2_1 saq2_2  ...  bq29 bq30_1  bq30_2 bq30_3  knowcode
# 0     27127       4      4       4      4  ...    40   4000    2600           304003
# 1     27128       5      6       5      6  ...    40   4000    3000           221401
# 2     27129       3      4       3      4  ...    48   4300    3000           815001
# 3     27130       4      5       2      3  ...    40   3500    3300           304003
# 4     27131       5      6       4      5  ...    40   5700    2700           140201
# ...     ...     ...    ...     ...    ...  ...   ...    ...     ...    ...       ...
# 8117  35244       4      6       3      5  ...    40   5100    4000           121105
# 8118  35245       3      4       4      5  ...    45   3100    2600            26102
# 8119  35246       5      6       3      4  ...    40   8000    3000            31301
# 8120  35247       5      6       5      5  ...    40   5700    3200           154105
# 8121  35248       2      5       4      6  ...    46   3700    2700            14201
#
# [8122 rows x 185 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-e615400841af> in <module>()
# ----> 1 know_train[0].head() # 2017년도 샘플
#
# IndexError: list index out of range

# %% [markdown]
# # 전처리
#
# 데이터의 빈 셀에 None값이 아닌 ' '처럼 공백으로 들어가있기 때문에 is_null등의 함수로 결측치를 찾아낼 수 없습니다.
#
# 공백이 있는 컬럼은 '0'으로 대체하였습니다.

# %%
for df in know_train:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# ## 라벨 인코딩
#
# 숫자로 변환할 수 있는 컬럼은 라벨 인코딩을 사용하지 않았습니다.
#
# string이나 object컬럼은 라벨인코더를 이용해 변환하였으며 추후 test셋에 사용해야하기 때문에 년도별, 컬럼별로 dictionary를 이용해 저장하였습니다

# %%
from sklearn.preprocessing import LabelEncoder
years = ['2017', '2018', '2019', '2020']

year_encoder = {}

for year, df in zip(years, know_train):
    print(year)
    encoders = {}
    
    for col in df.columns:
        if col == 'ID':
            continue
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = LabelEncoder()
            df[col] = df[col].map(str)
            df[col] = encoder.fit_transform(df[col])
            encoders[col] = encoder
            
            
    year_encoder[year] = encoders
# Out:
# 2017
# 2018
# 2019
# 2020

# %% [markdown]
# # X, y 구분 및 모델 학습
#
# 이번 대회에서 맞춰야 할 값은 knowcode입니다.
#
# ID와 knowcode를 제외한 나머지 feature를 X, knowcode를 정답 y로 두어 모델을 학습하였습니다.
#
# 베이스라인에서는 의사결정나무와 랜덤포레스트를 선정하였습니다

# %%
train_data = {}
for year, df in zip(years, know_train):
    train_data[year] = {'X': df.iloc[:, 1:-1], # ID제외
                        'y': df.iloc[:, -1]}

# %% [markdown]
# ## 의사결정나무

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

dt_models = {}

for year in tqdm(years):
    model = DecisionTreeClassifier(random_state=123456)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    dt_models[year] = model
# Out:
# 100%|██████████| 4/4 [00:10<00:00,  2.59s/it]

# %% [markdown]
# ## 랜덤포레스트

# %%
rf_models = {}

for year in tqdm(years):
    model = RandomForestClassifier(n_estimators=100, random_state=123456, n_jobs=8)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    rf_models[year] = model
# Out:
# 100%|██████████| 4/4 [00:12<00:00,  3.23s/it]

# %% [markdown]
# ## Testset 불러오기
#
# 마찬가지로 년도별로 DataFrame으로 불러온 후 리스트에 할당합니

# %%
know_test = [pd.read_csv(path) for path in sorted(glob('./test/*.csv'))]
know_test[0].head() # 2017년도 test 샘플
# Out:
#    idx  aq1_1 aq1_2  aq2_1 aq2_2  aq3_1 aq3_2  aq4_1 aq4_2  aq5_1  ... bq36  \
# 0    0      3     4      2     2      3     3      1            3  ...    2
# 1    1      5     5      3     5      5     5      5     5      4  ...    1
# 2    2      5     5      5     4      5     4      1            1  ...    1
# 3    3      4     5      5     6      4     6      3     4      4  ...    1
# 4    4      5     6      4     5      4     5      1            1  ...    1
#
#    bq37 bq38  bq38_1 bq39_1  bq39_2 bq40  bq41_1 bq41_2  bq41_3
# 0    26    3     비서학      1       1    1    3000           2300
# 1    57    4     농화학      1       1    1    5500           2500
# 2    31    4    신문방송      1       1    1    4300           4000
# 3    35    6      화학      1       1    1    4100           3000
# 4    36    4    광고홍보      1       1    1    2800           2000
#
# [5 rows x 155 columns]

# %% [markdown]
# Train set과 마찬가지로 평균, '0'으로 대체하였습니다

# %%
for df in know_test:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# Train에 사용하였던 라벨인코더를 이용해서 카테고리를 정수로 변환합니다.
#
# 만약 Test변수가 Train 라벨인코더의 클래스에 없을경우 -1로 처리합니다

# %%
years = ['2017', '2018', '2019', '2020']

for year, df in zip(years, know_test):
    print(year)
    encoders = {}
    
    for col in df.columns:
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = year_encoder[year][col]
            df[col] = df[col].map(str)
            category_map = {category: idx for idx, category in enumerate(encoder.classes_)}
            df[col] = df[col].apply(lambda x: category_map[x] if x in category_map else -1) # train set에서 보지못한 카테고리변수 -1(UNK) 처리
# Out:
# 2017
# 2018
# 2019
# 2020

# %% [markdown]
# ### 데이터 처리 및 라벨인코딩 후

# %%
know_train[0]['aq1_1'].value_counts()
# Out:
# 3    3116
# 4    3007
# 2    1706
# 5    1072
# 1     585
# Name: aq1_1, dtype: int64

# %%
know_test[0].head() # 2017년도 test 샘플
# Out:
#    idx  aq1_1  aq1_2  aq2_1  aq2_2  aq3_1  aq3_2  aq4_1  aq4_2  aq5_1  ...  \
# 0    0      3      4      2      2      3      3      1      0      3  ...
# 1    1      5      5      3      5      5      5      5      5      4  ...
# 2    2      5      5      5      4      5      4      1      0      1  ...
# 3    3      4      5      5      6      4      6      3      4      4  ...
# 4    4      5      6      4      5      4      5      1      0      1  ...
#
#    bq36  bq37  bq38  bq38_1  bq39_1  bq39_2  bq40  bq41_1  bq41_2  bq41_3
# 0     2    26     3     497       1       1     1    3000       0    2300
# 1     1    57     4     287       1       1     1    5500       0    2500
# 2     1    31     4     705       1       1     1    4300       0    4000
# 3     1    35     6    1423       1       1     1    4100       0    3000
# 4     1    36     4     141       1       1     1    2800       0    2000
#
# [5 rows x 155 columns]

# %% [markdown]
# ## 테스트셋 추출 및 학습
#
# ID 값을 제외한 나머지 데이터를 이용하여 모델에 넣어 추론합니다.

# %%
test_data = {}
for year, df in zip(years, know_test):
    test_data[year] =  {'X': df.iloc[:,1:]}

# %% [markdown]
# ### 의사결정나무로 예측

# %%
dt_predicts = [] 

for year in tqdm(years):
    pred = dt_models[year].predict(test_data[year]['X'])
    dt_predicts.extend(pred)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 16.97it/s]

# %% [markdown]
# ### 랜덤포레스트로 예측

# %%
rf_predicts = [] 

for year in tqdm(years):
    pred = rf_models[year].predict(test_data[year]['X'])
    rf_predicts.extend(pred)
# Out:
# 100%|██████████| 4/4 [00:04<00:00,  1.25s/it]

# %% [markdown]
# # 제출

# %%
submission = pd.read_csv('sample_submission.csv') # sample submission 불러오기

# %%
submission['knowcode'] = rf_predicts

submission.to_csv('submission.csv', index=False)
